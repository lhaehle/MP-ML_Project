# %%
import pandas as pd
import numpy as np
import os
from sqlalchemy import create_engine
import time
import pdb
import bdb  # Added to handle BdbQuit
from collections import Counter

# %%
if 1: # Create SQLAlchemy engine
    connection_string = (
        f"mssql+pyodbc://{"LouisHaehle"}:{"QuiltStanceCurler51"}"
        f"@10.0.30.16:1433/RTID_SourceData"
        f"?driver=ODBC+Driver+17+for+SQL+Server"
        f"&TrustServerCertificate=yes"
        f"&Connection+Timeout=5"
        )
    engine = create_engine(connection_string)

# %%
# Query all rows from the US_HY_NVR_TEST_2023_2025_REDO table
live_query = """
    SELECT [REPORT_YEAR_WEEK]
      ,[VEH_AT_PHYS_LOC]
      ,[INV_LST_PRCE_AMT]
      ,[INV_MSRP_AMT]
      ,[VIN_SOLD]
      ,[INV_MIN_VIN_SOLD_DT]
      ,[DAYS_LSTD_BFR_SLD]
      ,[SRC_VEH_FIRST_SCRAPED_DT]
      ,[TRIM_DESCRIPTION]
      ,[NVI_OWNSHP_DT]
      ,[NVI_EFCTV_START_DT]
      ,[NVI_CENSUS_TRACT]
      ,[NVI_RPT_YYYYMM]
      ,[SLS_REPORT_YEAR_MONTH]
      ,[SALES_DT]
      ,[CATG_CD]
      ,[INV_CENSUS_TRACT]
      ,[INV_CONTROL_NBR]
      ,[INV_DEALER_NAME]
      ,[INV_TOWN_NAME]
      ,[INV_STATE_ABBRV]
      ,[SLS_CENSUS_TRACT]
      ,[SLS_CONTROL_NBR]
      ,[SLS_DEALER_NAME]
      ,[SLS_TOWN_NAME]
      ,[SLS_STATE_ABBRV]
      ,[NVI_CONTROL_NBR]
      ,[NVI_DEALER_NAME]
      ,[NVI_TOWN_NAME]
      ,[NVI_STATE_ABBRV]
      ,[MAKE_DESC]
      ,[MODEL_DESC]
      ,[SERIES_TEXT]
      ,[FUEL_DESC]
      ,[SEGMENT_DESC]
      ,[ADVNC_VEH_TYPE_DESC]
      ,[VEH_MDL_YR]
      ,[MODEL_KEY_SHORT]
      ,[SLS_VEHICLE_COUNT]
      ,[INV_COUNT]
    FROM [SPGM_Live].[SPGM_Weekly_INV_NVI_SLS_20251107]
"""

# Execute the query and fetch all rows
full_df_live = pd.read_sql(live_query, engine)

# Display the shape and first few rows of the DataFrame
print(f"Total rows fetched: {len(full_df_live):,}")
print(full_df_live.head())
# Out:
# Total rows fetched: 30,625,458
#   REPORT_YEAR_WEEK VEH_AT_PHYS_LOC  INV_LST_PRCE_AMT  INV_MSRP_AMT  VIN_SOLD  \
# 0          2025-42               Y           38778.0       39528.0       0.0
# 1          2025-36               Y           58560.0       67810.0       0.0
# 2          2025-38               Y           64569.0       62774.0       2.0
# 3          2025-41               Y           65633.0       69580.0       0.0
# 4          2025-37               N           33161.0       34130.0       0.0
#
#   INV_MIN_VIN_SOLD_DT  DAYS_LSTD_BFR_SLD SRC_VEH_FIRST_SCRAPED_DT  \
# 0          1899-12-30             -999.0               2025-08-05
# 1          1899-12-30             -999.0               2024-11-14
# 2          2025-09-30               62.0               2025-07-30
# 3          1899-12-30             -999.0               2025-09-28
# 4          1899-12-30             -999.0               2025-07-12
#
#   TRIM_DESCRIPTION NVI_OWNSHP_DT  ...   MAKE_DESC MODEL_DESC SERIES_TEXT  \
# 0               SE    1899-12-30  ...  VOLKSWAGEN        GTI          SE
# 1   1500 ELEVATION    1899-12-30  ...         GMC     SIERRA         15P
# 2         350 BASE    2025-10-08  ...       LEXUS         TX         350
# 3       150 TREMOR    1899-12-30  ...        FORD   F SERIES         150
# 4        PREFERRED    1899-12-30  ...       MAZDA  UNDEFINED         UND
#
#            FUEL_DESC                SEGMENT_DESC ADVNC_VEH_TYPE_DESC  \
# 0           GASOLINE                *COMPACT CAR            Gasoline
# 1           GASOLINE                LARGE PICKUP            Gasoline
# 2           GASOLINE              MID LUXURY SUV            Gasoline
# 3           GASOLINE                LARGE PICKUP            Gasoline
# 4  UNKNOWN OR GLIDER  OLDER VEHICLE / UNASSIGNED            Gasoline
#
#   VEH_MDL_YR MODEL_KEY_SHORT SLS_VEHICLE_COUNT INV_COUNT
# 0       2025          151467               0.0       1.0
# 1       2025          149256               0.0       1.0
# 2       2025          150410               0.0       1.0
# 3       2025          127478               0.0       1.0
# 4       2025          149222               0.0       1.0
#
# [5 rows x 40 columns]

# %%
def analyze_duplicates_with_variations(df, duplicate_check_columns, variation_columns, 
                                       sample_groups=10, export_to_excel=False, 
                                       output_file='duplicate_analysis.xlsx'):
    """
    Find duplicates based on specific columns and analyze what varies in other columns.
    
    Parameters:
    df: DataFrame to analyze
    duplicate_check_columns: List of column names to check for duplicates
    variation_columns: List of column names to check for variations within duplicate groups
    sample_groups: Number of duplicate groups to display (default: 10)
    export_to_excel: Whether to export full results to Excel (default: False)
    output_file: Excel filename if export_to_excel=True
    
    Returns:
    DataFrame with duplicate groups and their variations
    """
    print(f"Analyzing duplicates in {len(df):,} rows...")
    print(f"Checking duplicates on: {duplicate_check_columns}")
    print(f"Analyzing variations in: {variation_columns}")
    print("=" * 80)
    
    # Find duplicates based on specified columns
    is_duplicate = df.duplicated(subset=duplicate_check_columns, keep=False)
    num_duplicates = is_duplicate.sum()
    num_unique = (~df.duplicated(subset=duplicate_check_columns)).sum()
    
    # Calculate the number of duplicate groups (unique combinations that appear more than once)
    num_duplicate_groups = len(df[is_duplicate].drop_duplicates(subset=duplicate_check_columns))
    
    print(f"\nDuplicate Summary:")
    print(f"  Total rows: {len(df):,}")
    print(f"  Unique combinations (total): {num_unique:,}")
    print(f"  Duplicate rows: {num_duplicates:,} ({100*num_duplicates/len(df):.2f}%)")
    print(f"  Number of duplicate groups: {num_duplicate_groups:,}")
    print(f"  Average rows per duplicate group: {num_duplicates/num_duplicate_groups:.1f}")
    
    if num_duplicates == 0:
        print("\nNo duplicates found!")
        return None
    
    # Get all duplicate rows
    duplicate_rows = df[is_duplicate].copy()
    
    # Analyze variations within each duplicate group
    print(f"\n{'=' * 80}")
    print(f"Analyzing variations in duplicate groups...")
    print(f"{'=' * 80}\n")
    
    # Group by duplicate check columns and analyze variations
    all_columns = duplicate_check_columns + variation_columns
    grouped = duplicate_rows[all_columns].groupby(duplicate_check_columns)
    
    results = []
    for name, group in grouped:
        group_size = len(group)
        
        # For each variation column, count unique values
        variations = {}
        for col in variation_columns:
            unique_vals = group[col].dropna().unique()
            variations[f'{col}_unique_count'] = len(unique_vals)
            variations[f'{col}_values'] = ', '.join([str(v) for v in unique_vals[:5]])  # First 5 values
            if len(unique_vals) > 5:
                variations[f'{col}_values'] += f' ... ({len(unique_vals)} total)'
        
        # Create result row
        result_row = {
            'duplicate_group_size': group_size,
        }
        
        # Add duplicate check column values
        if isinstance(name, tuple):
            for i, col in enumerate(duplicate_check_columns):
                result_row[col] = name[i]
        else:
            result_row[duplicate_check_columns[0]] = name
        
        # Add variation statistics
        result_row.update(variations)
        results.append(result_row)
    
    # Create results DataFrame
    results_df = pd.DataFrame(results)
    results_df = results_df.sort_values('duplicate_group_size', ascending=False)
    
    # Display sample groups
    print(f"Top {sample_groups} duplicate groups by size:")
    print("-" * 80)
    
    for idx, row in results_df.head(sample_groups).iterrows():
        print(f"\nGroup size: {row['duplicate_group_size']:,} rows")
        
        # Print duplicate check column values
        for col in duplicate_check_columns:
            print(f"  {col}: {row[col]}")
        
        # Print variations
        print(f"  Variations:")
        for col in variation_columns:
            unique_count = row[f'{col}_unique_count']
            values = row[f'{col}_values']
            print(f"    {col}: {unique_count} unique values - [{values}]")
        print("-" * 80)
    
    # Export results if requested
    if export_to_excel:
        num_results = len(results_df)
        max_excel_rows = 1048576
        
        if num_results > max_excel_rows:
            # Too large for Excel, use CSV instead
            csv_file = output_file.replace('.xlsx', '.csv')
            results_df.to_csv(csv_file, index=False)
            print(f"\n⚠️  Results too large for Excel ({num_results:,} rows > {max_excel_rows:,} limit)")
            print(f"✓ Full results exported to CSV: {csv_file}")
            
            # Also export top 100k to Excel for easier viewing
            excel_sample_file = output_file.replace('.xlsx', '_top100k.xlsx')
            results_df.head(100000).to_excel(excel_sample_file, index=False, sheet_name='Top_100k_Groups')
            print(f"✓ Top 100,000 groups exported to Excel: {excel_sample_file}")
        else:
            results_df.to_excel(output_file, index=False, sheet_name='Duplicate_Analysis')
            print(f"\n✓ Full results exported to: {output_file}")
    
    return results_df

# %%
duplicate_check_cols = ['INV_MIN_VIN_SOLD_DT', 'SRC_VEH_FIRST_SCRAPED_DT', 'TRIM_DESCRIPTION', 'INV_CENSUS_TRACT', 'INV_CONTROL_NBR', 'INV_DEALER_NAME', 'INV_TOWN_NAME', 'INV_STATE_ABBRV', 'MAKE_DESC', 'MODEL_DESC', 'SERIES_TEXT', 'FUEL_DESC', 'SEGMENT_DESC', 'ADVNC_VEH_TYPE_DESC', 'MODEL_KEY_SHORT', 'INV_COUNT']

# Removed 'INV_MIN_VIN_SOLD_DT' from variation_cols since it's already in duplicate_check_cols
variation_cols = ['VEH_AT_PHYS_LOC', 'VIN_SOLD', 'DAYS_LSTD_BFR_SLD', 'INV_LST_PRCE_AMT', 'INV_MSRP_AMT', 'SALES_DT', 'SLS_CONTROL_NBR', 'NVI_CONTROL_NBR']

# %%
# Run duplicate analysis


results = analyze_duplicates_with_variations(
    df=full_df_live,
    duplicate_check_columns=duplicate_check_cols,
    variation_columns=variation_cols,
    sample_groups=20,  # Show top 20 duplicate groups
    export_to_excel=True,  # Export full results to Excel
    output_file='duplicate_analysis_results.xlsx'
)
# Out:
# Analyzing duplicates in 30,625,458 rows...
# Checking duplicates on: ['INV_MIN_VIN_SOLD_DT', 'SRC_VEH_FIRST_SCRAPED_DT', 'TRIM_DESCRIPTION', 'INV_CENSUS_TRACT', 'INV_CONTROL_NBR', 'INV_DEALER_NAME', 'INV_TOWN_NAME', 'INV_STATE_ABBRV', 'MAKE_DESC', 'MODEL_DESC', 'SERIES_TEXT', 'FUEL_DESC', 'SEGMENT_DESC', 'ADVNC_VEH_TYPE_DESC', 'MODEL_KEY_SHORT', 'INV_COUNT']
# Analyzing variations in: ['VEH_AT_PHYS_LOC', 'VIN_SOLD', 'DAYS_LSTD_BFR_SLD', 'INV_LST_PRCE_AMT', 'INV_MSRP_AMT', 'SALES_DT', 'SLS_CONTROL_NBR', 'NVI_CONTROL_NBR']
# ================================================================================
#
# Duplicate Summary:
#   Total rows: 30,625,458
#   Unique combinations (total): 6,287,548
#   Duplicate rows: 29,657,088 (96.84%)
#   Number of duplicate groups: 5,319,178
#   Average rows per duplicate group: 5.6
#
# Duplicate Summary:
#   Total rows: 30,625,458
#   Unique combinations (total): 6,287,548
#   Duplicate rows: 29,657,088 (96.84%)
#   Number of duplicate groups: 5,319,178
#   Average rows per duplicate group: 5.6
#
# ================================================================================
# Analyzing variations in duplicate groups...
# ================================================================================
#
#
# ================================================================================
# Analyzing variations in duplicate groups...
# ================================================================================
#
# Top 20 duplicate groups by size:
# --------------------------------------------------------------------------------
#
# Group size: 424 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-10-01 00:00:00
#   TRIM_DESCRIPTION: SE
#   INV_CENSUS_TRACT: 06037007017
#   INV_CONTROL_NBR: 0267603
#   INV_DEALER_NAME: JAGUAR SANTA MONICA
#   INV_TOWN_NAME: SANTA MONICA
#   INV_STATE_ABBRV: CA
#   MAKE_DESC: LAND ROVER
#   MODEL_DESC: RANGE ROVER
#   SERIES_TEXT: SE
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: PREMIUM LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 148823
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [N]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 145 unique values - [159095.0, 130900.0, 159950.0, 151325.0, 150330.0 ... (145 total)]
#     INV_MSRP_AMT: 145 unique values - [159095.0, 130900.0, 159950.0, 151325.0, 150330.0 ... (145 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [, 0198307]
# --------------------------------------------------------------------------------
#
# Group size: 395 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12099000068
#   INV_CONTROL_NBR: 0012023
#   INV_DEALER_NAME: MERCEDES BENZ OF DELRAY
#   INV_TOWN_NAME: DELRAY BEACH
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 54 unique values - [55705.0, 55255.0, 60180.0, 56130.0, 63955.0 ... (54 total)]
#     INV_MSRP_AMT: 54 unique values - [55705.0, 55255.0, 60180.0, 56130.0, 63955.0 ... (54 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 394 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12086000004
#   INV_CONTROL_NBR: 0307393
#   INV_DEALER_NAME: MERCEDES BENZ OF MIAMI
#   INV_TOWN_NAME: MIAMI
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 54 unique values - [55330.0, 59455.0, 60655.0, 59390.0, 58090.0 ... (54 total)]
#     INV_MSRP_AMT: 54 unique values - [55330.0, 59455.0, 60655.0, 59390.0, 58090.0 ... (54 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 391 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12011000304
#   INV_CONTROL_NBR: 0127169
#   INV_DEALER_NAME: MERCEDES BENZ OF POMPANO
#   INV_TOWN_NAME: POMPANO BEACH
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 54 unique values - [57370.0, 63105.0, 59705.0, 60585.0, 54335.0 ... (54 total)]
#     INV_MSRP_AMT: 54 unique values - [57370.0, 63105.0, 59705.0, 60585.0, 54335.0 ... (54 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 387 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12011000433
#   INV_CONTROL_NBR: 0002717
#   INV_DEALER_NAME: MERCEDES BENZ OF FORT LAUDERDALE
#   INV_TOWN_NAME: FORT LAUDERDALE
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 54 unique values - [55705.0, 57005.0, 58090.0, 59605.0, 63105.0 ... (54 total)]
#     INV_MSRP_AMT: 54 unique values - [55705.0, 57005.0, 58090.0, 59605.0, 63105.0 ... (54 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 387 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12011000106
#   INV_CONTROL_NBR: 0212823
#   INV_DEALER_NAME: MERCEDES BENZ OF COCONUT CREEK
#   INV_TOWN_NAME: COCONUT CREEK
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [Y, N]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 54 unique values - [55255.0, 63155.0, 54335.0, 58090.0, 60180.0 ... (54 total)]
#     INV_MSRP_AMT: 54 unique values - [55255.0, 63155.0, 54335.0, 58090.0, 60180.0 ... (54 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 380 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12011001103
#   INV_CONTROL_NBR: 0157460
#   INV_DEALER_NAME: MERCEDES BENZ OF PEMBROKE PINES
#   INV_TOWN_NAME: PEMBROKE PINES
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [N]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 53 unique values - [65355.0, 63955.0, 57370.0, 60655.0, 63155.0 ... (53 total)]
#     INV_MSRP_AMT: 53 unique values - [65355.0, 63955.0, 57370.0, 60655.0, 63155.0 ... (53 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 340 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-09-03 00:00:00
#   TRIM_DESCRIPTION: SEL
#   INV_CENSUS_TRACT: 12017004506
#   INV_CONTROL_NBR: 0006960
#   INV_DEALER_NAME: JENKINS NISSAN HOMOSASSA
#   INV_TOWN_NAME: HOMOSASSA
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: HYUNDAI
#   MODEL_DESC: TUCSON
#   SERIES_TEXT: SEL
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: *SUBCOMPACT SUV
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 148925
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [N]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 214 unique values - [31324.0, 28114.0, 32252.0, 32521.0, 27627.0 ... (214 total)]
#     INV_MSRP_AMT: 50 unique values - [35185.0, 33780.0, 33250.0, 35300.0, 33220.0 ... (50 total)]
#     SALES_DT: 2 unique values - [1899-12-30 00:00:00, 2025-11-05 00:00:00]
#     SLS_CONTROL_NBR: 3 unique values - [, 0442925, 0023465]
#     NVI_CONTROL_NBR: 3 unique values - [, 0023465, 0217649]
# --------------------------------------------------------------------------------
#
# Group size: 339 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-10-09 00:00:00
#   TRIM_DESCRIPTION: SE
#   INV_CENSUS_TRACT: 01073000108
#   INV_CONTROL_NBR: 0307061
#   INV_DEALER_NAME: LAND ROVER BIRMINGHAM
#   INV_TOWN_NAME: IRONDALE
#   INV_STATE_ABBRV: AL
#   MAKE_DESC: LAND ROVER
#   MODEL_DESC: RANGE ROVER
#   SERIES_TEXT: SE
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: PREMIUM LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 148823
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 198 unique values - [128392.0, 142500.0, 121225.0, 121205.0, 118801.0 ... (198 total)]
#     INV_MSRP_AMT: 173 unique values - [128395.0, 142500.0, 121225.0, 121205.0, 118805.0 ... (173 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [, 0198307]
# --------------------------------------------------------------------------------
#
# Group size: 335 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12086000004
#   INV_CONTROL_NBR: 0307393
#   INV_DEALER_NAME: MERCEDES BENZ OF MIAMI
#   INV_TOWN_NAME: MIAMI
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [Y, N]
#     VIN_SOLD: 2 unique values - [3.0, 0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 52 unique values - [52505.0, 59455.0, 52990.0, 53255.0, 55955.0 ... (52 total)]
#     INV_MSRP_AMT: 52 unique values - [52505.0, 59455.0, 52990.0, 53255.0, 55955.0 ... (52 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 332 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-10-09 00:00:00
#   TRIM_DESCRIPTION: SE
#   INV_CENSUS_TRACT: 08045009516
#   INV_CONTROL_NBR: 0267517
#   INV_DEALER_NAME: LAND ROVER ROARING FORK
#   INV_TOWN_NAME: GLENWOOD SPRINGS
#   INV_STATE_ABBRV: CO
#   MAKE_DESC: LAND ROVER
#   MODEL_DESC: RANGE ROVER
#   SERIES_TEXT: SE
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: PREMIUM LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 148823
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 171 unique values - [131090.0, 131170.0, 127745.0, 144175.0, 132135.0 ... (171 total)]
#     INV_MSRP_AMT: 171 unique values - [131090.0, 131170.0, 127745.0, 144175.0, 132135.0 ... (171 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [, 0198307]
# --------------------------------------------------------------------------------
#
# Group size: 322 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12011000433
#   INV_CONTROL_NBR: 0002717
#   INV_DEALER_NAME: MERCEDES BENZ OF FORT LAUDERDALE
#   INV_TOWN_NAME: FORT LAUDERDALE
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [Y, N]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 52 unique values - [50835.0, 52690.0, 54305.0, 55370.0, 53255.0 ... (52 total)]
#     INV_MSRP_AMT: 52 unique values - [50835.0, 52690.0, 54305.0, 55370.0, 53255.0 ... (52 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 318 rows
#   INV_MIN_VIN_SOLD_DT: 2025-09-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-09-03 00:00:00
#   TRIM_DESCRIPTION: LUXE
#   INV_CENSUS_TRACT: 36059005213
#   INV_CONTROL_NBR: 0163027
#   INV_DEALER_NAME: INFINITI CITY MASSAPEQUA
#   INV_TOWN_NAME: MASSAPEQUA
#   INV_STATE_ABBRV: NY
#   MAKE_DESC: INFINITI
#   MODEL_DESC: QX60
#   SERIES_TEXT: LUX
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: MID LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 153192
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [Y]
#     VIN_SOLD: 2 unique values - [2.0, 1.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [27.0]
#     INV_LST_PRCE_AMT: 16 unique values - [60850.0, 61985.0, 62390.0, 62185.0, 60059.0 ... (16 total)]
#     INV_MSRP_AMT: 15 unique values - [60850.0, 61985.0, 62390.0, 62185.0, 64145.0 ... (15 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [0005170, 0163027]
# --------------------------------------------------------------------------------
#
# Group size: 315 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-07-29 00:00:00
#   TRIM_DESCRIPTION: 2500
#   INV_CENSUS_TRACT: 53033000093
#   INV_CONTROL_NBR: 0048177
#   INV_DEALER_NAME: SMART CENTER OF SEATTLE
#   INV_TOWN_NAME: SEATTLE
#   INV_STATE_ABBRV: WA
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: SPRINTER
#   SERIES_TEXT: 250
#   FUEL_DESC: DIESEL
#   SEGMENT_DESC: LARGE MPV
#   ADVNC_VEH_TYPE_DESC: Diesel
#   MODEL_KEY_SHORT: 149630
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 49 unique values - [83373.0, 70777.0, 80730.0, 66655.0, 76755.0 ... (49 total)]
#     INV_MSRP_AMT: 49 unique values - [83373.0, 70777.0, 80730.0, 66655.0, 76755.0 ... (49 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [, 0331930]
# --------------------------------------------------------------------------------
#
# Group size: 314 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12099000068
#   INV_CONTROL_NBR: 0012023
#   INV_DEALER_NAME: MERCEDES BENZ OF DELRAY
#   INV_TOWN_NAME: DELRAY BEACH
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 51 unique values - [55955.0, 57155.0, 66875.0, 55605.0, 55435.0 ... (51 total)]
#     INV_MSRP_AMT: 51 unique values - [55955.0, 57155.0, 66875.0, 55605.0, 55435.0 ... (51 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 303 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12011000304
#   INV_CONTROL_NBR: 0127169
#   INV_DEALER_NAME: MERCEDES BENZ OF POMPANO
#   INV_TOWN_NAME: POMPANO BEACH
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [Y, N]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 51 unique values - [55685.0, 52920.0, 54380.0, 57705.0, 53555.0 ... (51 total)]
#     INV_MSRP_AMT: 51 unique values - [55685.0, 52920.0, 54380.0, 57705.0, 53555.0 ... (51 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 299 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12011000106
#   INV_CONTROL_NBR: 0212823
#   INV_DEALER_NAME: MERCEDES BENZ OF COCONUT CREEK
#   INV_TOWN_NAME: COCONUT CREEK
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 51 unique values - [53555.0, 56665.0, 55105.0, 63470.0, 53630.0 ... (51 total)]
#     INV_MSRP_AMT: 51 unique values - [53555.0, 56665.0, 55105.0, 63470.0, 53630.0 ... (51 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 298 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12011001103
#   INV_CONTROL_NBR: 0157460
#   INV_DEALER_NAME: MERCEDES BENZ OF PEMBROKE PINES
#   INV_TOWN_NAME: PEMBROKE PINES
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 50 unique values - [51880.0, 56055.0, 56905.0, 56665.0, 56085.0 ... (50 total)]
#     INV_MSRP_AMT: 50 unique values - [51880.0, 56055.0, 56905.0, 56665.0, 56085.0 ... (50 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 290 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-22 00:00:00
#   TRIM_DESCRIPTION: SR5
#   INV_CENSUS_TRACT: 04013000820
#   INV_CONTROL_NBR: 0192955
#   INV_DEALER_NAME: AVONDALE TOYOTA
#   INV_TOWN_NAME: AVONDALE
#   INV_STATE_ABBRV: AZ
#   MAKE_DESC: TOYOTA
#   MODEL_DESC: TACOMA
#   SERIES_TEXT: MTL
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: MIDSIZE PICKUP
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 150562
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [Y]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 65 unique values - [44692.0, 41289.0, 40795.0, 41389.0, 41493.0 ... (65 total)]
#     INV_MSRP_AMT: 64 unique values - [47538.0, 43664.0, 43173.0, 43853.0, 43934.0 ... (64 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 277 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-10-09 00:00:00
#   TRIM_DESCRIPTION: SE
#   INV_CENSUS_TRACT: 48201005533
#   INV_CONTROL_NBR: 0170405
#   INV_DEALER_NAME: LAND ROVER HOUSTON NORTH
#   INV_TOWN_NAME: HOUSTON
#   INV_STATE_ABBRV: TX
#   MAKE_DESC: LAND ROVER
#   MODEL_DESC: RANGE ROVER
#   SERIES_TEXT: SE
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: PREMIUM LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 148823
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [N]
#     VIN_SOLD: 2 unique values - [3.0, 0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 164 unique values - [143925.0, 134825.0, 152930.0, 118761.0, 154145.0 ... (164 total)]
#     INV_MSRP_AMT: 143 unique values - [143925.0, 134825.0, 152930.0, 118765.0, 154145.0 ... (143 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [, 0198307]
# --------------------------------------------------------------------------------
# Top 20 duplicate groups by size:
# --------------------------------------------------------------------------------
#
# Group size: 424 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-10-01 00:00:00
#   TRIM_DESCRIPTION: SE
#   INV_CENSUS_TRACT: 06037007017
#   INV_CONTROL_NBR: 0267603
#   INV_DEALER_NAME: JAGUAR SANTA MONICA
#   INV_TOWN_NAME: SANTA MONICA
#   INV_STATE_ABBRV: CA
#   MAKE_DESC: LAND ROVER
#   MODEL_DESC: RANGE ROVER
#   SERIES_TEXT: SE
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: PREMIUM LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 148823
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [N]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 145 unique values - [159095.0, 130900.0, 159950.0, 151325.0, 150330.0 ... (145 total)]
#     INV_MSRP_AMT: 145 unique values - [159095.0, 130900.0, 159950.0, 151325.0, 150330.0 ... (145 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [, 0198307]
# --------------------------------------------------------------------------------
#
# Group size: 395 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12099000068
#   INV_CONTROL_NBR: 0012023
#   INV_DEALER_NAME: MERCEDES BENZ OF DELRAY
#   INV_TOWN_NAME: DELRAY BEACH
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 54 unique values - [55705.0, 55255.0, 60180.0, 56130.0, 63955.0 ... (54 total)]
#     INV_MSRP_AMT: 54 unique values - [55705.0, 55255.0, 60180.0, 56130.0, 63955.0 ... (54 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 394 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12086000004
#   INV_CONTROL_NBR: 0307393
#   INV_DEALER_NAME: MERCEDES BENZ OF MIAMI
#   INV_TOWN_NAME: MIAMI
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 54 unique values - [55330.0, 59455.0, 60655.0, 59390.0, 58090.0 ... (54 total)]
#     INV_MSRP_AMT: 54 unique values - [55330.0, 59455.0, 60655.0, 59390.0, 58090.0 ... (54 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 391 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12011000304
#   INV_CONTROL_NBR: 0127169
#   INV_DEALER_NAME: MERCEDES BENZ OF POMPANO
#   INV_TOWN_NAME: POMPANO BEACH
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 54 unique values - [57370.0, 63105.0, 59705.0, 60585.0, 54335.0 ... (54 total)]
#     INV_MSRP_AMT: 54 unique values - [57370.0, 63105.0, 59705.0, 60585.0, 54335.0 ... (54 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 387 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12011000433
#   INV_CONTROL_NBR: 0002717
#   INV_DEALER_NAME: MERCEDES BENZ OF FORT LAUDERDALE
#   INV_TOWN_NAME: FORT LAUDERDALE
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 54 unique values - [55705.0, 57005.0, 58090.0, 59605.0, 63105.0 ... (54 total)]
#     INV_MSRP_AMT: 54 unique values - [55705.0, 57005.0, 58090.0, 59605.0, 63105.0 ... (54 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 387 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12011000106
#   INV_CONTROL_NBR: 0212823
#   INV_DEALER_NAME: MERCEDES BENZ OF COCONUT CREEK
#   INV_TOWN_NAME: COCONUT CREEK
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [Y, N]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 54 unique values - [55255.0, 63155.0, 54335.0, 58090.0, 60180.0 ... (54 total)]
#     INV_MSRP_AMT: 54 unique values - [55255.0, 63155.0, 54335.0, 58090.0, 60180.0 ... (54 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 380 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 12011001103
#   INV_CONTROL_NBR: 0157460
#   INV_DEALER_NAME: MERCEDES BENZ OF PEMBROKE PINES
#   INV_TOWN_NAME: PEMBROKE PINES
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [N]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 53 unique values - [65355.0, 63955.0, 57370.0, 60655.0, 63155.0 ... (53 total)]
#     INV_MSRP_AMT: 53 unique values - [65355.0, 63955.0, 57370.0, 60655.0, 63155.0 ... (53 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 340 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-09-03 00:00:00
#   TRIM_DESCRIPTION: SEL
#   INV_CENSUS_TRACT: 12017004506
#   INV_CONTROL_NBR: 0006960
#   INV_DEALER_NAME: JENKINS NISSAN HOMOSASSA
#   INV_TOWN_NAME: HOMOSASSA
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: HYUNDAI
#   MODEL_DESC: TUCSON
#   SERIES_TEXT: SEL
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: *SUBCOMPACT SUV
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 148925
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [N]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 214 unique values - [31324.0, 28114.0, 32252.0, 32521.0, 27627.0 ... (214 total)]
#     INV_MSRP_AMT: 50 unique values - [35185.0, 33780.0, 33250.0, 35300.0, 33220.0 ... (50 total)]
#     SALES_DT: 2 unique values - [1899-12-30 00:00:00, 2025-11-05 00:00:00]
#     SLS_CONTROL_NBR: 3 unique values - [, 0442925, 0023465]
#     NVI_CONTROL_NBR: 3 unique values - [, 0023465, 0217649]
# --------------------------------------------------------------------------------
#
# Group size: 339 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-10-09 00:00:00
#   TRIM_DESCRIPTION: SE
#   INV_CENSUS_TRACT: 01073000108
#   INV_CONTROL_NBR: 0307061
#   INV_DEALER_NAME: LAND ROVER BIRMINGHAM
#   INV_TOWN_NAME: IRONDALE
#   INV_STATE_ABBRV: AL
#   MAKE_DESC: LAND ROVER
#   MODEL_DESC: RANGE ROVER
#   SERIES_TEXT: SE
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: PREMIUM LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 148823
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 198 unique values - [128392.0, 142500.0, 121225.0, 121205.0, 118801.0 ... (198 total)]
#     INV_MSRP_AMT: 173 unique values - [128395.0, 142500.0, 121225.0, 121205.0, 118805.0 ... (173 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [, 0198307]
# --------------------------------------------------------------------------------
#
# Group size: 335 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12086000004
#   INV_CONTROL_NBR: 0307393
#   INV_DEALER_NAME: MERCEDES BENZ OF MIAMI
#   INV_TOWN_NAME: MIAMI
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [Y, N]
#     VIN_SOLD: 2 unique values - [3.0, 0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 52 unique values - [52505.0, 59455.0, 52990.0, 53255.0, 55955.0 ... (52 total)]
#     INV_MSRP_AMT: 52 unique values - [52505.0, 59455.0, 52990.0, 53255.0, 55955.0 ... (52 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 332 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-10-09 00:00:00
#   TRIM_DESCRIPTION: SE
#   INV_CENSUS_TRACT: 08045009516
#   INV_CONTROL_NBR: 0267517
#   INV_DEALER_NAME: LAND ROVER ROARING FORK
#   INV_TOWN_NAME: GLENWOOD SPRINGS
#   INV_STATE_ABBRV: CO
#   MAKE_DESC: LAND ROVER
#   MODEL_DESC: RANGE ROVER
#   SERIES_TEXT: SE
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: PREMIUM LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 148823
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 171 unique values - [131090.0, 131170.0, 127745.0, 144175.0, 132135.0 ... (171 total)]
#     INV_MSRP_AMT: 171 unique values - [131090.0, 131170.0, 127745.0, 144175.0, 132135.0 ... (171 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [, 0198307]
# --------------------------------------------------------------------------------
#
# Group size: 322 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12011000433
#   INV_CONTROL_NBR: 0002717
#   INV_DEALER_NAME: MERCEDES BENZ OF FORT LAUDERDALE
#   INV_TOWN_NAME: FORT LAUDERDALE
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [Y, N]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 52 unique values - [50835.0, 52690.0, 54305.0, 55370.0, 53255.0 ... (52 total)]
#     INV_MSRP_AMT: 52 unique values - [50835.0, 52690.0, 54305.0, 55370.0, 53255.0 ... (52 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 318 rows
#   INV_MIN_VIN_SOLD_DT: 2025-09-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-09-03 00:00:00
#   TRIM_DESCRIPTION: LUXE
#   INV_CENSUS_TRACT: 36059005213
#   INV_CONTROL_NBR: 0163027
#   INV_DEALER_NAME: INFINITI CITY MASSAPEQUA
#   INV_TOWN_NAME: MASSAPEQUA
#   INV_STATE_ABBRV: NY
#   MAKE_DESC: INFINITI
#   MODEL_DESC: QX60
#   SERIES_TEXT: LUX
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: MID LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 153192
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [Y]
#     VIN_SOLD: 2 unique values - [2.0, 1.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [27.0]
#     INV_LST_PRCE_AMT: 16 unique values - [60850.0, 61985.0, 62390.0, 62185.0, 60059.0 ... (16 total)]
#     INV_MSRP_AMT: 15 unique values - [60850.0, 61985.0, 62390.0, 62185.0, 64145.0 ... (15 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [0005170, 0163027]
# --------------------------------------------------------------------------------
#
# Group size: 315 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-07-29 00:00:00
#   TRIM_DESCRIPTION: 2500
#   INV_CENSUS_TRACT: 53033000093
#   INV_CONTROL_NBR: 0048177
#   INV_DEALER_NAME: SMART CENTER OF SEATTLE
#   INV_TOWN_NAME: SEATTLE
#   INV_STATE_ABBRV: WA
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: SPRINTER
#   SERIES_TEXT: 250
#   FUEL_DESC: DIESEL
#   SEGMENT_DESC: LARGE MPV
#   ADVNC_VEH_TYPE_DESC: Diesel
#   MODEL_KEY_SHORT: 149630
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 49 unique values - [83373.0, 70777.0, 80730.0, 66655.0, 76755.0 ... (49 total)]
#     INV_MSRP_AMT: 49 unique values - [83373.0, 70777.0, 80730.0, 66655.0, 76755.0 ... (49 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [, 0331930]
# --------------------------------------------------------------------------------
#
# Group size: 314 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12099000068
#   INV_CONTROL_NBR: 0012023
#   INV_DEALER_NAME: MERCEDES BENZ OF DELRAY
#   INV_TOWN_NAME: DELRAY BEACH
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 51 unique values - [55955.0, 57155.0, 66875.0, 55605.0, 55435.0 ... (51 total)]
#     INV_MSRP_AMT: 51 unique values - [55955.0, 57155.0, 66875.0, 55605.0, 55435.0 ... (51 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 303 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12011000304
#   INV_CONTROL_NBR: 0127169
#   INV_DEALER_NAME: MERCEDES BENZ OF POMPANO
#   INV_TOWN_NAME: POMPANO BEACH
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [Y, N]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 51 unique values - [55685.0, 52920.0, 54380.0, 57705.0, 53555.0 ... (51 total)]
#     INV_MSRP_AMT: 51 unique values - [55685.0, 52920.0, 54380.0, 57705.0, 53555.0 ... (51 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 299 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12011000106
#   INV_CONTROL_NBR: 0212823
#   INV_DEALER_NAME: MERCEDES BENZ OF COCONUT CREEK
#   INV_TOWN_NAME: COCONUT CREEK
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 51 unique values - [53555.0, 56665.0, 55105.0, 63470.0, 53630.0 ... (51 total)]
#     INV_MSRP_AMT: 51 unique values - [53555.0, 56665.0, 55105.0, 63470.0, 53630.0 ... (51 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 298 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-08 00:00:00
#   TRIM_DESCRIPTION: 300
#   INV_CENSUS_TRACT: 12011001103
#   INV_CONTROL_NBR: 0157460
#   INV_DEALER_NAME: MERCEDES BENZ OF PEMBROKE PINES
#   INV_TOWN_NAME: PEMBROKE PINES
#   INV_STATE_ABBRV: FL
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 154515
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 2 unique values - [N, Y]
#     VIN_SOLD: 2 unique values - [0.0, 3.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 50 unique values - [51880.0, 56055.0, 56905.0, 56665.0, 56085.0 ... (50 total)]
#     INV_MSRP_AMT: 50 unique values - [51880.0, 56055.0, 56905.0, 56665.0, 56085.0 ... (50 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 290 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-22 00:00:00
#   TRIM_DESCRIPTION: SR5
#   INV_CENSUS_TRACT: 04013000820
#   INV_CONTROL_NBR: 0192955
#   INV_DEALER_NAME: AVONDALE TOYOTA
#   INV_TOWN_NAME: AVONDALE
#   INV_STATE_ABBRV: AZ
#   MAKE_DESC: TOYOTA
#   MODEL_DESC: TACOMA
#   SERIES_TEXT: MTL
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: MIDSIZE PICKUP
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 150562
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [Y]
#     VIN_SOLD: 1 unique values - [0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 65 unique values - [44692.0, 41289.0, 40795.0, 41389.0, 41493.0 ... (65 total)]
#     INV_MSRP_AMT: 64 unique values - [47538.0, 43664.0, 43173.0, 43853.0, 43934.0 ... (64 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 1 unique values - []
# --------------------------------------------------------------------------------
#
# Group size: 277 rows
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-10-09 00:00:00
#   TRIM_DESCRIPTION: SE
#   INV_CENSUS_TRACT: 48201005533
#   INV_CONTROL_NBR: 0170405
#   INV_DEALER_NAME: LAND ROVER HOUSTON NORTH
#   INV_TOWN_NAME: HOUSTON
#   INV_STATE_ABBRV: TX
#   MAKE_DESC: LAND ROVER
#   MODEL_DESC: RANGE ROVER
#   SERIES_TEXT: SE
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: PREMIUM LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 148823
#   INV_COUNT: 1.0
#   Variations:
#     VEH_AT_PHYS_LOC: 1 unique values - [N]
#     VIN_SOLD: 2 unique values - [3.0, 0.0]
#     DAYS_LSTD_BFR_SLD: 1 unique values - [-999.0]
#     INV_LST_PRCE_AMT: 164 unique values - [143925.0, 134825.0, 152930.0, 118761.0, 154145.0 ... (164 total)]
#     INV_MSRP_AMT: 143 unique values - [143925.0, 134825.0, 152930.0, 118765.0, 154145.0 ... (143 total)]
#     SALES_DT: 1 unique values - [1899-12-30 00:00:00]
#     SLS_CONTROL_NBR: 1 unique values - []
#     NVI_CONTROL_NBR: 2 unique values - [, 0198307]
# --------------------------------------------------------------------------------
#
# ⚠️  Results too large for Excel (5,319,178 rows > 1,048,576 limit)
# ✓ Full results exported to CSV: duplicate_analysis_results.csv
#
# ⚠️  Results too large for Excel (5,319,178 rows > 1,048,576 limit)
# ✓ Full results exported to CSV: duplicate_analysis_results.csv
# ✓ Top 100,000 groups exported to Excel: duplicate_analysis_results_top100k.xlsx
# ✓ Top 100,000 groups exported to Excel: duplicate_analysis_results_top100k.xlsx

# %%
# Find duplicate groups where INV_LST_PRCE_AMT varies
# Filter for groups where INV_LST_PRCE_AMT_unique_count > 1
price_varying_groups = results[results['INV_LST_PRCE_AMT_unique_count'] > 1].copy()

print(f"Found {len(price_varying_groups):,} duplicate groups where INV_LST_PRCE_AMT varies")
print(f"That's {100*len(price_varying_groups)/len(results):.2f}% of all duplicate groups")
print("\n" + "="*80)
print("Top 10 groups with price variations (sorted by group size):")
print("="*80)

# Show top 10 by group size
for idx, row in price_varying_groups.head(10).iterrows():
    print(f"\nGroup size: {row['duplicate_group_size']:,} rows")
    print(f"  INV_LST_PRCE_AMT: {row['INV_LST_PRCE_AMT_unique_count']} unique values - {row['INV_LST_PRCE_AMT_values']}")
    print(f"  INV_DEALER_NAME: {row['INV_DEALER_NAME']}")
    print(f"  MAKE_DESC: {row['MAKE_DESC']}")
    print(f"  MODEL_DESC: {row['MODEL_DESC']}")
    print("-"*80)

# %%
# Get the actual rows from the first duplicate group with price variations
# This will show you all the rows that belong to that group

if len(price_varying_groups) > 0:
    # Get the first group's identifying values
    first_group = price_varying_groups.iloc[0]
    
    print(f"Fetching all rows for the largest duplicate group with price variations...")
    print(f"Group size: {first_group['duplicate_group_size']:,} rows")
    print("="*80)
    
    # Build a filter to get all rows from this duplicate group
    filter_mask = pd.Series(True, index=full_df_live.index)
    for col in duplicate_check_cols:
        filter_mask &= (full_df_live[col] == first_group[col])
    
    # Get the actual rows
    example_group = full_df_live[filter_mask].copy()
    
    # Display key columns including the varying price
    display_cols = ['REPORT_YEAR_WEEK', 'VEH_AT_PHYS_LOC', 'INV_LST_PRCE_AMT', 'INV_MSRP_AMT', 
                    'VIN_SOLD', 'DAYS_LSTD_BFR_SLD', 'INV_DEALER_NAME', 'MAKE_DESC', 'MODEL_DESC']
    
    print(f"\nShowing key columns for this duplicate group:")
    print(example_group[display_cols].to_string())
    
    print(f"\n\nINV_LST_PRCE_AMT value counts in this group:")
    print(example_group['INV_LST_PRCE_AMT'].value_counts())
else:
    print("No duplicate groups with price variations found!")

# %%
def get_duplicate_insights(df, duplicate_check_columns, variation_columns):
    """
    Get comprehensive high-level insights about duplicates in the dataset.
    
    Parameters:
    df: DataFrame to analyze
    duplicate_check_columns: List of column names to check for duplicates
    variation_columns: List of column names to check for variations
    
    Returns:
    Dictionary with various insights
    """
    print("=" * 80)
    print("HIGH-LEVEL DUPLICATE INSIGHTS")
    print("=" * 80)
    
    # Basic duplicate statistics
    is_duplicate = df.duplicated(subset=duplicate_check_columns, keep=False)
    num_duplicates = is_duplicate.sum()
    num_unique = (~df.duplicated(subset=duplicate_check_columns)).sum()
    duplicate_rows = df[is_duplicate].copy()
    
    # Count duplicate groups
    duplicate_groups = duplicate_rows.groupby(duplicate_check_columns).size().reset_index(name='group_size')
    num_duplicate_groups = len(duplicate_groups)
    
    print(f"\n1. OVERALL STATISTICS:")
    print(f"   Total rows: {len(df):,}")
    print(f"   Unique combinations: {num_unique:,} ({100*num_unique/len(df):.2f}%)")
    print(f"   Duplicate rows: {num_duplicates:,} ({100*num_duplicates/len(df):.2f}%)")
    print(f"   Number of duplicate groups: {num_duplicate_groups:,}")
    if num_duplicate_groups > 0:
        print(f"   Average rows per duplicate group: {num_duplicates/num_duplicate_groups:.2f}")
    
    # Group size distribution
    print(f"\n2. DUPLICATE GROUP SIZE DISTRIBUTION:")
    size_distribution = duplicate_groups['group_size'].value_counts().sort_index()
    print(f"   Group Size  |  Count  |  % of Groups")
    print(f"   " + "-" * 40)
    for size, count in size_distribution.items():
        pct = 100 * count / num_duplicate_groups
        print(f"   {size:>5} rows  |  {count:>6,}  |  {pct:>5.2f}%")
    
    # Largest groups
    print(f"\n3. TOP 10 LARGEST DUPLICATE GROUPS:")
    top_groups = duplicate_groups.nlargest(10, 'group_size')
    for idx, row in top_groups.iterrows():
        print(f"   Group with {row['group_size']:,} rows")
    
    # Variation analysis summary
    print(f"\n4. VARIATION PATTERNS ACROSS ALL DUPLICATE GROUPS:")
    variation_stats = {}
    
    for col in variation_columns:
        # For each duplicate group, count unique values in variation column
        group_variations = duplicate_rows.groupby(duplicate_check_columns)[col].nunique()
        
        # How many groups have multiple different values?
        groups_with_variation = (group_variations > 1).sum()
        pct_with_variation = 100 * groups_with_variation / num_duplicate_groups if num_duplicate_groups > 0 else 0
        
        variation_stats[col] = {
            'groups_with_variation': groups_with_variation,
            'pct_with_variation': pct_with_variation,
            'max_unique_values': group_variations.max() if len(group_variations) > 0 else 0
        }
        
        print(f"   {col}:")
        print(f"      {groups_with_variation:,} groups ({pct_with_variation:.1f}%) have variations")
        print(f"      Max unique values in a single group: {variation_stats[col]['max_unique_values']}")
    
    print("\n" + "=" * 80)
    
    return {
        'total_rows': len(df),
        'unique_combinations': num_unique,
        'duplicate_rows': num_duplicates,
        'duplicate_groups': num_duplicate_groups,
        'size_distribution': size_distribution,
        'variation_stats': variation_stats,
        'duplicate_groups_df': duplicate_groups
    }

# %%
def inspect_duplicate_group(df, duplicate_check_columns, variation_columns, 
                           group_index=0, group_criteria=None, display_all_cols=False):
    """
    Inspect a specific duplicate group to see all rows and their variations.
    
    Parameters:
    df: DataFrame to analyze
    duplicate_check_columns: List of column names that define duplicates
    variation_columns: List of column names to show variations
    group_index: Index of group to inspect (0 = largest group, 1 = 2nd largest, etc.)
    group_criteria: Dict to filter specific group (e.g., {'VIN_SOLD': '12345', 'MAKE_DESC': 'FORD'})
    display_all_cols: If True, show all columns; if False, show only check + variation columns
    
    Returns:
    DataFrame with all rows from the selected duplicate group
    """
    # Find all duplicate rows
    is_duplicate = df.duplicated(subset=duplicate_check_columns, keep=False)
    duplicate_rows = df[is_duplicate].copy()
    
    if len(duplicate_rows) == 0:
        print("No duplicates found!")
        return None
    
    # Select group based on criteria or index
    if group_criteria:
        # Filter by specific criteria
        mask = pd.Series(True, index=duplicate_rows.index)
        for col, val in group_criteria.items():
            mask &= (duplicate_rows[col] == val)
        
        group_rows = duplicate_rows[mask]
        
        if len(group_rows) == 0:
            print(f"No duplicate group found matching criteria: {group_criteria}")
            return None
        
        print(f"Found duplicate group matching criteria: {group_criteria}")
        
    else:
        # Get group by index (sorted by size)
        grouped = duplicate_rows.groupby(duplicate_check_columns).size().reset_index(name='group_size')
        grouped = grouped.sort_values('group_size', ascending=False)
        
        if group_index >= len(grouped):
            print(f"Group index {group_index} out of range. Only {len(grouped)} duplicate groups exist.")
            return None
        
        # Get the group at specified index
        target_group = grouped.iloc[group_index]
        
        # Build filter for this group
        mask = pd.Series(True, index=duplicate_rows.index)
        for col in duplicate_check_columns:
            mask &= (duplicate_rows[col] == target_group[col])
        
        group_rows = duplicate_rows[mask]
        print(f"Inspecting duplicate group #{group_index} (largest = 0)")
        print(f"Group size: {len(group_rows):,} rows")
    
    # Display the duplicate check column values (what's the same)
    print("\n" + "=" * 80)
    print("DUPLICATE CHECK COLUMNS (these are IDENTICAL across all rows):")
    print("=" * 80)
    for col in duplicate_check_columns:
        value = group_rows[col].iloc[0]
        print(f"  {col}: {value}")
    
    # Display variation statistics
    print("\n" + "=" * 80)
    print("VARIATION COLUMNS (these DIFFER across rows):")
    print("=" * 80)
    for col in variation_columns:
        unique_vals = group_rows[col].dropna().unique()
        null_count = group_rows[col].isna().sum()
        
        print(f"\n  {col}:")
        print(f"    Unique values: {len(unique_vals)}")
        print(f"    Null values: {null_count}")
        
        if len(unique_vals) <= 10:
            # Show all values if there aren't too many
            value_counts = group_rows[col].value_counts(dropna=False)
            for val, count in value_counts.items():
                print(f"      {val}: {count} rows")
        else:
            # Show top 10 most common
            print(f"    Top 10 most common values:")
            value_counts = group_rows[col].value_counts(dropna=False).head(10)
            for val, count in value_counts.items():
                print(f"      {val}: {count} rows")
            print(f"    ... and {len(unique_vals) - 10} more unique values")
    
    # Return the actual rows
    print("\n" + "=" * 80)
    print("ACTUAL ROWS IN THIS DUPLICATE GROUP:")
    print("=" * 80)
    
    if display_all_cols:
        display_df = group_rows
    else:
        # Show only relevant columns
        cols_to_show = duplicate_check_columns + variation_columns
        # Only include columns that actually exist in the dataframe
        cols_to_show = [col for col in cols_to_show if col in group_rows.columns]
        display_df = group_rows[cols_to_show]
    
    print(f"\nShowing {len(display_df)} rows:")
    print(f"(Use display_all_cols=True to see all columns)")
    
    return display_df

# %%
# Step 1: Get overall insights about duplicates
insights = get_duplicate_insights(full_df_live, duplicate_check_cols, variation_cols)

# The insights dictionary contains useful information:
# - insights['stats']: Overall statistics
# - insights['group_size_distribution']: How many groups have 2 rows, 3 rows, etc.
# - insights['top_groups']: Top 10 largest duplicate groups
# - insights['duplicate_groups_df']: Full DataFrame for custom analysis
# Out:
# ================================================================================
# HIGH-LEVEL DUPLICATE INSIGHTS
# ================================================================================
#
# 1. OVERALL STATISTICS:
#    Total rows: 30,625,458
#    Unique combinations: 6,287,548 (20.53%)
#    Duplicate rows: 29,657,088 (96.84%)
#    Number of duplicate groups: 5,319,178
#    Average rows per duplicate group: 5.58
#
# 2. DUPLICATE GROUP SIZE DISTRIBUTION:
#    Group Size  |  Count  |  % of Groups
#    ----------------------------------------
#        2 rows  |  815,323  |  15.33%
#        3 rows  |  721,400  |  13.56%
#        4 rows  |  665,614  |  12.51%
#        5 rows  |  552,308  |  10.38%
#        6 rows  |  474,764  |   8.93%
#        7 rows  |  1,686,936  |  31.71%
#        8 rows  |  53,394  |   1.00%
#        9 rows  |  22,961  |   0.43%
#       10 rows  |  43,837  |   0.82%
#       11 rows  |  12,610  |   0.24%
#       12 rows  |  43,389  |   0.82%
#       13 rows  |  10,826  |   0.20%
#       14 rows  |  127,423  |   2.40%
#       15 rows  |   9,844  |   0.19%
#       16 rows  |   5,824  |   0.11%
#       17 rows  |   3,663  |   0.07%
#       18 rows  |   7,721  |   0.15%
#       19 rows  |   3,475  |   0.07%
#       20 rows  |   5,154  |   0.10%
#       21 rows  |  21,861  |   0.41%
#       22 rows  |   1,803  |   0.03%
#       23 rows  |   1,486  |   0.03%
#       24 rows  |   2,951  |   0.06%
#       25 rows  |   1,663  |   0.03%
#       26 rows  |   1,294  |   0.02%
#       27 rows  |   1,175  |   0.02%
#       28 rows  |   6,214  |   0.12%
#       29 rows  |     642  |   0.01%
#       30 rows  |   1,217  |   0.02%
#       31 rows  |     584  |   0.01%
#       32 rows  |     574  |   0.01%
#       33 rows  |     533  |   0.01%
#       34 rows  |     516  |   0.01%
#       35 rows  |   2,349  |   0.04%
#       36 rows  |     539  |   0.01%
#       37 rows  |     330  |   0.01%
#       38 rows  |     338  |   0.01%
#       39 rows  |     289  |   0.01%
#       40 rows  |     456  |   0.01%
#       41 rows  |     311  |   0.01%
#       42 rows  |   1,048  |   0.02%
#       43 rows  |     190  |   0.00%
#       44 rows  |     211  |   0.00%
#       45 rows  |     238  |   0.00%
#       46 rows  |     157  |   0.00%
#       47 rows  |     181  |   0.00%
#       48 rows  |     215  |   0.00%
#       49 rows  |     447  |   0.01%
#       50 rows  |     157  |   0.00%
#       51 rows  |     122  |   0.00%
#       52 rows  |     116  |   0.00%
#       53 rows  |     124  |   0.00%
#       54 rows  |     119  |   0.00%
#       55 rows  |     122  |   0.00%
#       56 rows  |     253  |   0.00%
#       57 rows  |      62  |   0.00%
#       58 rows  |      70  |   0.00%
#       59 rows  |      74  |   0.00%
#       60 rows  |     104  |   0.00%
#       61 rows  |      65  |   0.00%
#       62 rows  |      63  |   0.00%
#       63 rows  |     145  |   0.00%
#       64 rows  |      60  |   0.00%
#       65 rows  |      45  |   0.00%
#       66 rows  |      60  |   0.00%
#       67 rows  |      52  |   0.00%
#       68 rows  |      50  |   0.00%
#       69 rows  |      40  |   0.00%
#       70 rows  |      74  |   0.00%
#       71 rows  |      49  |   0.00%
#       72 rows  |      38  |   0.00%
#       73 rows  |      20  |   0.00%
#       74 rows  |      30  |   0.00%
#       75 rows  |      11  |   0.00%
#       76 rows  |      19  |   0.00%
#       77 rows  |      33  |   0.00%
#       78 rows  |      18  |   0.00%
#       79 rows  |      20  |   0.00%
#       80 rows  |      28  |   0.00%
#       81 rows  |      23  |   0.00%
#       82 rows  |      16  |   0.00%
#       83 rows  |      14  |   0.00%
#       84 rows  |      32  |   0.00%
#       85 rows  |      24  |   0.00%
#       86 rows  |      17  |   0.00%
#       87 rows  |       6  |   0.00%
#       88 rows  |      16  |   0.00%
#       89 rows  |      11  |   0.00%
#       90 rows  |      22  |   0.00%
#       91 rows  |      24  |   0.00%
#       92 rows  |      15  |   0.00%
#       93 rows  |      10  |   0.00%
#       94 rows  |      10  |   0.00%
#       95 rows  |      21  |   0.00%
#       96 rows  |      14  |   0.00%
#       97 rows  |      15  |   0.00%
#       98 rows  |      19  |   0.00%
#       99 rows  |      15  |   0.00%
#      100 rows  |      10  |   0.00%
#      101 rows  |       3  |   0.00%
#      102 rows  |       6  |   0.00%
#      103 rows  |       3  |   0.00%
#      104 rows  |       5  |   0.00%
#      105 rows  |      13  |   0.00%
#      106 rows  |      10  |   0.00%
#      107 rows  |       6  |   0.00%
#      108 rows  |       3  |   0.00%
#      109 rows  |       3  |   0.00%
#      110 rows  |      11  |   0.00%
#      111 rows  |       5  |   0.00%
#      112 rows  |       5  |   0.00%
#      113 rows  |       7  |   0.00%
#      114 rows  |       4  |   0.00%
#      115 rows  |       3  |   0.00%
#      116 rows  |       8  |   0.00%
#      117 rows  |      12  |   0.00%
#      118 rows  |       7  |   0.00%
#      119 rows  |       9  |   0.00%
#      120 rows  |       4  |   0.00%
#      121 rows  |       4  |   0.00%
#      122 rows  |       2  |   0.00%
#      123 rows  |       5  |   0.00%
#      124 rows  |      11  |   0.00%
#      125 rows  |       3  |   0.00%
#      126 rows  |       7  |   0.00%
#      127 rows  |       1  |   0.00%
#      128 rows  |       3  |   0.00%
#      129 rows  |       9  |   0.00%
#      130 rows  |       6  |   0.00%
#      131 rows  |       4  |   0.00%
#      132 rows  |       2  |   0.00%
#      133 rows  |       2  |   0.00%
#      134 rows  |       2  |   0.00%
#      135 rows  |       3  |   0.00%
#      136 rows  |       1  |   0.00%
#      137 rows  |       5  |   0.00%
#      138 rows  |       5  |   0.00%
#      140 rows  |       4  |   0.00%
#      141 rows  |       1  |   0.00%
#      142 rows  |       2  |   0.00%
#      143 rows  |       2  |   0.00%
#      145 rows  |       1  |   0.00%
#      146 rows  |       1  |   0.00%
#      147 rows  |       5  |   0.00%
#      151 rows  |       2  |   0.00%
#      153 rows  |       1  |   0.00%
#      154 rows  |       1  |   0.00%
#      155 rows  |       5  |   0.00%
#      159 rows  |       1  |   0.00%
#      160 rows  |       5  |   0.00%
#      161 rows  |       7  |   0.00%
#      162 rows  |       1  |   0.00%
#      163 rows  |       2  |   0.00%
#      164 rows  |       1  |   0.00%
#      165 rows  |       1  |   0.00%
#      167 rows  |       1  |   0.00%
#      168 rows  |       3  |   0.00%
#      169 rows  |       2  |   0.00%
#      170 rows  |       2  |   0.00%
#      172 rows  |       1  |   0.00%
#      173 rows  |       1  |   0.00%
#      174 rows  |       1  |   0.00%
#      175 rows  |       1  |   0.00%
#      176 rows  |       2  |   0.00%
#      179 rows  |       2  |   0.00%
#      180 rows  |       1  |   0.00%
#      181 rows  |       2  |   0.00%
#      182 rows  |       1  |   0.00%
#      183 rows  |       1  |   0.00%
#      184 rows  |       3  |   0.00%
#      185 rows  |       2  |   0.00%
#      186 rows  |       1  |   0.00%
#      187 rows  |       2  |   0.00%
#      188 rows  |       1  |   0.00%
#      189 rows  |       1  |   0.00%
#      191 rows  |       1  |   0.00%
#      193 rows  |       1  |   0.00%
#      195 rows  |       1  |   0.00%
#      196 rows  |       1  |   0.00%
#      198 rows  |       1  |   0.00%
#      202 rows  |       1  |   0.00%
#      203 rows  |       2  |   0.00%
#      205 rows  |       1  |   0.00%
#      209 rows  |       2  |   0.00%
#      213 rows  |       1  |   0.00%
#      215 rows  |       1  |   0.00%
#      216 rows  |       1  |   0.00%
#      220 rows  |       1  |   0.00%
#      223 rows  |       2  |   0.00%
#      224 rows  |       1  |   0.00%
#      228 rows  |       1  |   0.00%
#      232 rows  |       1  |   0.00%
#      233 rows  |       1  |   0.00%
#      235 rows  |       1  |   0.00%
#      237 rows  |       1  |   0.00%
#      238 rows  |       1  |   0.00%
#      239 rows  |       1  |   0.00%
#      240 rows  |       1  |   0.00%
#      258 rows  |       1  |   0.00%
#      277 rows  |       1  |   0.00%
#      290 rows  |       1  |   0.00%
#      298 rows  |       1  |   0.00%
#      299 rows  |       1  |   0.00%
#      303 rows  |       1  |   0.00%
#      314 rows  |       1  |   0.00%
#      315 rows  |       1  |   0.00%
#      318 rows  |       1  |   0.00%
#      322 rows  |       1  |   0.00%
#      332 rows  |       1  |   0.00%
#      335 rows  |       1  |   0.00%
#      339 rows  |       1  |   0.00%
#      340 rows  |       1  |   0.00%
#      380 rows  |       1  |   0.00%
#      387 rows  |       2  |   0.00%
#      391 rows  |       1  |   0.00%
#      394 rows  |       1  |   0.00%
#      395 rows  |       1  |   0.00%
#      424 rows  |       1  |   0.00%
#
# 3. TOP 10 LARGEST DUPLICATE GROUPS:
#    Group with 424 rows
#    Group with 395 rows
#    Group with 394 rows
#    Group with 391 rows
#    Group with 387 rows
#    Group with 387 rows
#    Group with 380 rows
#    Group with 340 rows
#    Group with 339 rows
#    Group with 335 rows
#
# 4. VARIATION PATTERNS ACROSS ALL DUPLICATE GROUPS:
#    VEH_AT_PHYS_LOC:
#       390,000 groups (7.3%) have variations
#       Max unique values in a single group: 2
#    VIN_SOLD:
#       623,929 groups (11.7%) have variations
#       Max unique values in a single group: 2
#    DAYS_LSTD_BFR_SLD:
#       0 groups (0.0%) have variations
#       Max unique values in a single group: 1
#    INV_LST_PRCE_AMT:
#       2,597,909 groups (48.8%) have variations
#       Max unique values in a single group: 214
#    INV_MSRP_AMT:
#       876,298 groups (16.5%) have variations
#       Max unique values in a single group: 173
#    SALES_DT:
#       17,648 groups (0.3%) have variations
#       Max unique values in a single group: 4
#    SLS_CONTROL_NBR:
#       17,381 groups (0.3%) have variations
#       Max unique values in a single group: 5
#    NVI_CONTROL_NBR:
#       133,062 groups (2.5%) have variations
#       Max unique values in a single group: 10
#
# ================================================================================

# %%
# Export duplicate groups to Excel with formatting for readability
from openpyxl import load_workbook
from openpyxl.styles import Font, Alignment, PatternFill
from openpyxl.utils import get_column_letter

# Get the duplicate groups DataFrame
all_duplicate_groups = insights['duplicate_groups_df']

# Limit to top groups (Excel can't handle all 4.4M rows)
# Export top 100k largest groups - these are the most important ones
num_groups_to_export = min(100000, len(all_duplicate_groups))
top_duplicate_groups = all_duplicate_groups.head(num_groups_to_export)

print(f"Exporting top {num_groups_to_export:,} groups out of {len(all_duplicate_groups):,} total")
print(f"These groups contain {top_duplicate_groups['group_size'].sum():,} rows")

# Export to Excel
output_file = 'duplicate_groups_summary.xlsx'
top_duplicate_groups.to_excel(output_file, index=False, sheet_name='Duplicate_Groups')

# Load the workbook for formatting
wb = load_workbook(output_file)
ws = wb['Duplicate_Groups']

# Define styles
header_font = Font(bold=True, size=12, color='FFFFFF')
header_fill = PatternFill(start_color='366092', end_color='366092', fill_type='solid')
header_alignment = Alignment(horizontal='center', vertical='center', wrap_text=True)

cell_alignment = Alignment(horizontal='left', vertical='top', wrap_text=True)
number_alignment = Alignment(horizontal='right', vertical='center')

# Format header row
for col_num, col in enumerate(top_duplicate_groups.columns, 1):
    cell = ws.cell(row=1, column=col_num)
    cell.font = header_font
    cell.fill = header_fill
    cell.alignment = header_alignment

# Set column widths and apply formatting
for col_num, col in enumerate(top_duplicate_groups.columns, 1):
    col_letter = get_column_letter(col_num)
    
    # Set column width based on column type
    if col == 'group_size':
        ws.column_dimensions[col_letter].width = 15
        # Format group_size column
        for row_num in range(2, len(top_duplicate_groups) + 2):
            ws.cell(row=row_num, column=col_num).alignment = number_alignment
    elif col in ['TRIM_DESCRIPTION', 'INV_DEALER_NAME', 'MODEL_DESC']:
        ws.column_dimensions[col_letter].width = 35
        # Apply text alignment
        for row_num in range(2, len(top_duplicate_groups) + 2):
            ws.cell(row=row_num, column=col_num).alignment = cell_alignment
    elif col in ['MAKE_DESC', 'SERIES_TEXT', 'FUEL_DESC', 'SEGMENT_DESC', 
                 'ADVNC_VEH_TYPE_DESC', 'MODEL_KEY_SHORT']:
        ws.column_dimensions[col_letter].width = 25
        for row_num in range(2, len(top_duplicate_groups) + 2):
            ws.cell(row=row_num, column=col_num).alignment = cell_alignment
    elif col in ['INV_TOWN_NAME', 'INV_STATE_ABBRV']:
        ws.column_dimensions[col_letter].width = 20
        for row_num in range(2, len(top_duplicate_groups) + 2):
            ws.cell(row=row_num, column=col_num).alignment = cell_alignment
    elif col in ['INV_CONTROL_NBR', 'INV_CENSUS_TRACT']:
        ws.column_dimensions[col_letter].width = 18
        for row_num in range(2, len(top_duplicate_groups) + 2):
            ws.cell(row=row_num, column=col_num).alignment = cell_alignment
    else:
        ws.column_dimensions[col_letter].width = 22
        for row_num in range(2, len(top_duplicate_groups) + 2):
            ws.cell(row=row_num, column=col_num).alignment = cell_alignment

# Set row height for better readability
ws.row_dimensions[1].height = 30  # Header row
for row_num in range(2, min(1000, len(top_duplicate_groups) + 2)):  # First 1000 rows
    ws.row_dimensions[row_num].height = 20

# Add alternating row colors for easier reading
light_fill = PatternFill(start_color='F2F2F2', end_color='F2F2F2', fill_type='solid')
for row_num in range(2, len(top_duplicate_groups) + 2):
    if row_num % 2 == 0:
        for col_num in range(1, len(top_duplicate_groups.columns) + 1):
            ws.cell(row=row_num, column=col_num).fill = light_fill

# Freeze the header row
ws.freeze_panes = 'A2'

# Add auto-filter
ws.auto_filter.ref = ws.dimensions

# Save the formatted workbook
wb.save(output_file)

print(f"✓ Duplicate groups exported to: {output_file}")
print(f"  Groups exported: {len(top_duplicate_groups):,} (top {num_groups_to_export:,} largest)")
print(f"  Total groups in dataset: {len(all_duplicate_groups):,}")
print(f"  Rows covered by exported groups: {top_duplicate_groups['group_size'].sum():,}")
print(f"  Sorted by group_size (largest first)")
print(f"  Features: Formatted headers, wider columns, alternating row colors, frozen header, auto-filter")
# Out:
# Exporting top 100,000 groups out of 5,319,178 total
# These groups contain 700,062 rows
# ✓ Duplicate groups exported to: duplicate_groups_summary.xlsx
#   Groups exported: 100,000 (top 100,000 largest)
#   Total groups in dataset: 5,319,178
#   Rows covered by exported groups: 700,062
#   Sorted by group_size (largest first)
#   Features: Formatted headers, wider columns, alternating row colors, frozen header, auto-filter

# %% [markdown]
# ## Inspect Specific Duplicate Groups
#
# Now that you have the Excel summary, you can pick any group and see all the actual rows with all columns.

# %%
# Example 1: Look at the largest duplicate group (index 0) with ALL columns
largest_group_all_cols = inspect_duplicate_group(
    full_df_live,
    duplicate_check_cols,
    variation_cols,
    group_index=0,  # Largest group
    display_all_cols=True  # Show ALL 40 columns, not just duplicate_check + variation
)

# This will return a DataFrame with all rows from that group
largest_group_all_cols

# %%
# Example 2: Pick a specific group from your Excel file
# Say you found an interesting group in the Excel - row 10 for example
interesting_group = top_duplicate_groups.iloc[9]  # Row 10 (0-indexed)

# Build criteria from that row
criteria = {col: interesting_group[col] for col in duplicate_check_cols}

# Get all actual rows for this group with ALL columns
group_details = inspect_duplicate_group(
    full_df_live,
    duplicate_check_cols,
    variation_cols,
    group_criteria=criteria,
    display_all_cols=True  # Show all 40 columns
)

group_details

# %%
# Example 3: Export a specific group's rows to Excel for detailed examination
# Pick any group you're interested in
group_to_export = top_duplicate_groups.iloc[0]  # Largest group
criteria = {col: group_to_export[col] for col in duplicate_check_cols}

# Get all rows
group_rows = inspect_duplicate_group(
    full_df_live,
    duplicate_check_cols,
    variation_cols,
    group_criteria=criteria,
    display_all_cols=True
)

# Export to Excel
if group_rows is not None:
    excel_filename = f"duplicate_group_detail_{group_rows['MAKE_DESC'].iloc[0]}_{group_rows['MODEL_DESC'].iloc[0]}.xlsx"
    group_rows.to_excel(excel_filename, index=False)
    print(f"\n✓ Group details exported to: {excel_filename}")
    print(f"  Rows in group: {len(group_rows):,}")
    print(f"  All {len(group_rows.columns)} columns included")

# %% [markdown]
# ## Create Excel File with Summary + All Details
#
# This creates a multi-sheet Excel file where you can browse the summary and use filters to see detailed rows.

# %%
# Out:
# Preparing to export 29,933,432 duplicate rows...
# Across 4,400,732 duplicate groups
#
# ⚠️ Warning: 29,933,432 rows exceeds Excel limit of 1,048,576
# Will export top 1,038,576 rows (leaving room for headers and formulas)
#
# ✓ Exporting to Excel: duplicates_complete.xlsx
#   Formatting Summary sheet...
#   Formatting All_Duplicate_Rows sheet...
#   Adding row formatting...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 104
#     102 for row_num in range(2, min(10000, ws_details.max_row + 1)):
#     103     if row_num % 2 == 0:
# --> 104         for col_num in range(1, ws_details.max_column + 1):
#     105             ws_details.cell(row=row_num, column=col_num).fill = light_fill
#     107 wb.save(output_file)
#
# File c:\Users\LouisHaehle\.venvs\MP-ML-Project\Lib\site-packages\openpyxl\worksheet\worksheet.py:374, in Worksheet.max_column(self)
#     372 max_col = 1
#     373 if self._cells:
# --> 374     max_col = max(c[1] for c in self._cells)
#     375 return max_col
#
# File c:\Users\LouisHaehle\.venvs\MP-ML-Project\Lib\site-packages\openpyxl\worksheet\worksheet.py:374, in <genexpr>(.0)
#     372 max_col = 1
#     373 if self._cells:
# --> 374     max_col = max(c[1] for c in self._cells)
#     375 return max_col
#
# KeyboardInterrupt:

# %% [markdown]
# ## Analyze Which Columns Vary Within Duplicate Groups
#
# Check which columns actually differ within duplicate groups to understand what makes them "duplicates" vs truly different records.

# %%
def analyze_column_variations_in_duplicates(df, duplicate_check_columns):
    """
    For each column NOT used in duplicate detection, check how often it varies within duplicate groups.
    
    This helps identify which columns are actually different vs identical within duplicate groups.
    
    Parameters:
    df: DataFrame to analyze
    duplicate_check_columns: List of columns used to identify duplicates
    
    Returns:
    DataFrame with variation statistics for each column
    """
    print("Analyzing which columns vary within duplicate groups...")
    print("=" * 80)
    
    # Get duplicate rows
    is_duplicate = df.duplicated(subset=duplicate_check_columns, keep=False)
    duplicate_rows = df[is_duplicate].copy()
    
    if len(duplicate_rows) == 0:
        print("No duplicates found!")
        return None
    
    # Get all columns that are NOT in the duplicate check (these can potentially vary)
    all_columns = df.columns.tolist()
    columns_to_analyze = [col for col in all_columns if col not in duplicate_check_columns]
    
    print(f"\nTotal duplicate rows: {len(duplicate_rows):,}")
    print(f"Columns used for duplicate detection: {len(duplicate_check_columns)}")
    print(f"Columns to analyze for variations: {len(columns_to_analyze)}")
    print()
    
    # Group by duplicate check columns
    grouped = duplicate_rows.groupby(duplicate_check_columns)
    num_groups = len(grouped)
    
    print(f"Number of duplicate groups: {num_groups:,}")
    print()
    
    # For each column, calculate variation statistics
    variation_stats = []
    
    for col in columns_to_analyze:
        # Count how many unique values exist in each group for this column
        unique_counts = grouped[col].nunique()
        
        # Groups with variation (more than 1 unique value)
        groups_with_variation = (unique_counts > 1).sum()
        pct_groups_with_variation = 100 * groups_with_variation / num_groups
        
        # Groups with no variation (only 1 unique value or all null)
        groups_without_variation = num_groups - groups_with_variation
        pct_groups_without_variation = 100 * groups_without_variation / num_groups
        
        # Average number of unique values per group
        avg_unique_per_group = unique_counts.mean()
        max_unique_in_group = unique_counts.max()
        
        variation_stats.append({
            'column': col,
            'pct_groups_with_variation': pct_groups_with_variation,
            'avg_unique_per_group': avg_unique_per_group
        })
    
    # Create results DataFrame
    results_df = pd.DataFrame(variation_stats)
    
    # Sort by percentage of groups with variation (descending)
    results_df = results_df.sort_values('pct_groups_with_variation', ascending=False)
    
    return results_df

# Run the analysis
variation_analysis = analyze_column_variations_in_duplicates(full_df_live, duplicate_check_cols)

# Display results
print("\n" + "=" * 80)
print("COLUMN VARIATION ANALYSIS")
print("=" * 80)
print(f"\nColumns ranked by how often they vary within duplicate groups:\n")

# Format and display the results
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.width', 200)
pd.set_option('display.max_columns', None)

print(variation_analysis.to_string(index=False))

print("\n" + "=" * 80)
print("INTERPRETATION:")
print("=" * 80)
print("• High 'pct_groups_with_variation' = Column often differs within duplicate groups")
print("• Low 'pct_groups_with_variation' = Column usually identical within duplicate groups")
print("• 'avg_unique_per_group' shows average number of different values per group")
print("=" * 80)
# Out:
# Analyzing which columns vary within duplicate groups...
# ================================================================================
#
# Total duplicate rows: 29,657,088
# Columns used for duplicate detection: 16
# Columns to analyze for variations: 24
#
# Number of duplicate groups: 5,319,178
#
#
# ================================================================================
# COLUMN VARIATION ANALYSIS
# ================================================================================
#
# Columns ranked by how often they vary within duplicate groups:
#
#                column  pct_groups_with_variation  avg_unique_per_group
#      REPORT_YEAR_WEEK                  98.248696              4.847148
#      INV_LST_PRCE_AMT                  48.840422              1.873822
#          INV_MSRP_AMT                  16.474312              1.245404
#              VIN_SOLD                  11.729801              1.117298
#       VEH_AT_PHYS_LOC                   7.331960              1.073320
#      NVI_CENSUS_TRACT                   3.354710              1.042082
#         NVI_OWNSHP_DT                   2.662347              1.032254
#       NVI_CONTROL_NBR                   2.501552              1.026663
#    NVI_EFCTV_START_DT                   2.314907              1.024729
#        NVI_RPT_YYYYMM                   2.073892              1.021973
#       NVI_DEALER_NAME                   1.940131              1.020612
#         NVI_TOWN_NAME                   1.623108              1.017017
#       NVI_STATE_ABBRV                   1.119459              1.011454
#      SLS_CENSUS_TRACT                   0.336029              1.003503
#               CATG_CD                   0.332796              1.003365
#              SALES_DT                   0.331781              1.003386
#     SLS_VEHICLE_COUNT                   0.330991              1.003326
# SLS_REPORT_YEAR_MONTH                   0.329769              1.003316
#       SLS_DEALER_NAME                   0.326761              1.003314
#       SLS_CONTROL_NBR                   0.326761              1.003315
#         SLS_TOWN_NAME                   0.326686              1.003313
#       SLS_STATE_ABBRV                   0.325990              1.003279
#     DAYS_LSTD_BFR_SLD                   0.000000              1.000000
#            VEH_MDL_YR                   0.000000              1.000000
#
# ================================================================================
# INTERPRETATION:
# ================================================================================
# • High 'pct_groups_with_variation' = Column often differs within duplicate groups
# • Low 'pct_groups_with_variation' = Column usually identical within duplicate groups
# • 'avg_unique_per_group' shows average number of different values per group
# ================================================================================

# %%
# Export variation analysis to Excel with formatting
from openpyxl import load_workbook
from openpyxl.styles import Font, Alignment, PatternFill
from openpyxl.utils import get_column_letter

output_file = 'column_variation_analysis.xlsx'
variation_analysis.to_excel(output_file, index=False, sheet_name='Variation_Analysis')

# Load and format
wb = load_workbook(output_file)
ws = wb['Variation_Analysis']

# Header formatting
header_font = Font(bold=True, size=12, color='FFFFFF')
header_fill = PatternFill(start_color='366092', end_color='366092', fill_type='solid')
header_alignment = Alignment(horizontal='center', vertical='center', wrap_text=True)

for col_num in range(1, len(variation_analysis.columns) + 1):
    cell = ws.cell(row=1, column=col_num)
    cell.font = header_font
    cell.fill = header_fill
    cell.alignment = header_alignment

# Column widths
ws.column_dimensions['A'].width = 35  # column name
ws.column_dimensions['B'].width = 28  # pct_groups_with_variation
ws.column_dimensions['C'].width = 25  # avg_unique_per_group

# Format data rows
for row_num in range(2, len(variation_analysis) + 2):
    # Column name - left aligned
    ws.cell(row=row_num, column=1).alignment = Alignment(horizontal='left', vertical='center')
    
    # Numbers - right aligned with appropriate formatting
    for col_num in range(2, len(variation_analysis.columns) + 1):
        cell = ws.cell(row=row_num, column=col_num)
        cell.alignment = Alignment(horizontal='right', vertical='center')
        
        # Format percentage (column B)
        if col_num == 2:  # pct_groups_with_variation
            cell.number_format = '0.00'
        # Format decimals (column C)
        elif col_num == 3:  # avg_unique_per_group
            cell.number_format = '0.00'

# Alternating row colors
light_fill = PatternFill(start_color='F2F2F2', end_color='F2F2F2', fill_type='solid')
for row_num in range(2, len(variation_analysis) + 2):
    if row_num % 2 == 0:
        for col_num in range(1, len(variation_analysis.columns) + 1):
            ws.cell(row=row_num, column=col_num).fill = light_fill

# Freeze header
ws.freeze_panes = 'A2'

# Auto-filter
ws.auto_filter.ref = ws.dimensions

# Row heights
ws.row_dimensions[1].height = 40
for row_num in range(2, len(variation_analysis) + 2):
    ws.row_dimensions[row_num].height = 18

wb.save(output_file)

print(f"✓ Variation analysis exported to: {output_file}")
print(f"  {len(variation_analysis)} columns analyzed")
print(f"  Sorted by pct_groups_with_variation (highest first)")
print(f"  Features: Formatted headers, proper number formats, alternating colors, frozen header, auto-filter")
# Out:
# ✓ Variation analysis exported to: column_variation_analysis.xlsx
#   26 columns analyzed
#   Sorted by pct_groups_with_variation (highest first)
#   Features: Formatted headers, proper number formats, alternating colors, frozen header, auto-filter

# %% [markdown]
# ## Focus on REPORT_YEAR_WEEK Variations
#
# Since you suspect REPORT_YEAR_WEEK is the main differentiator, let's specifically analyze it.

# %%
def analyze_report_week_as_only_difference(df, duplicate_check_columns):
    """
    Specifically check if REPORT_YEAR_WEEK is the ONLY difference in duplicate groups.
    
    This identifies "true duplicates" where the same record appears in multiple weeks.
    """
    print("=" * 80)
    print("REPORT_YEAR_WEEK SPECIFIC ANALYSIS")
    print("=" * 80)
    
    # Get duplicate rows
    is_duplicate = df.duplicated(subset=duplicate_check_columns, keep=False)
    duplicate_rows = df[is_duplicate].copy()
    
    if len(duplicate_rows) == 0:
        print("No duplicates found!")
        return None
    
    # Group by duplicate check columns
    grouped = duplicate_rows.groupby(duplicate_check_columns)
    num_groups = len(grouped)
    
    # Get all columns except duplicate_check_columns and REPORT_YEAR_WEEK
    all_columns = df.columns.tolist()
    other_columns = [col for col in all_columns 
                     if col not in duplicate_check_columns and col != 'REPORT_YEAR_WEEK']
    
    print(f"\nTotal duplicate groups: {num_groups:,}")
    print(f"Checking if REPORT_YEAR_WEEK is the ONLY varying column...")
    print()
    
    # Count groups where ONLY REPORT_YEAR_WEEK varies
    groups_only_week_varies = 0
    groups_week_and_others_vary = 0
    groups_week_constant = 0
    
    week_variation_details = []
    
    for name, group in grouped:
        # Check if REPORT_YEAR_WEEK varies in this group
        week_unique = group['REPORT_YEAR_WEEK'].nunique()
        week_varies = week_unique > 1
        
        # Check if ANY other column varies
        other_columns_vary = False
        varying_other_cols = []
        
        for col in other_columns:
            if group[col].nunique() > 1:
                other_columns_vary = True
                varying_other_cols.append(col)
        
        # Categorize this group
        if week_varies and not other_columns_vary:
            groups_only_week_varies += 1
            week_variation_details.append({
                'group_size': len(group),
                'num_weeks': week_unique,
                'weeks': sorted(group['REPORT_YEAR_WEEK'].unique()),
                'category': 'ONLY_WEEK_VARIES'
            })
        elif week_varies and other_columns_vary:
            groups_week_and_others_vary += 1
            week_variation_details.append({
                'group_size': len(group),
                'num_weeks': week_unique,
                'weeks': sorted(group['REPORT_YEAR_WEEK'].unique()),
                'other_varying_cols': varying_other_cols,
                'category': 'WEEK_AND_OTHERS_VARY'
            })
        else:
            groups_week_constant += 1
    
    # Calculate percentages
    pct_only_week = 100 * groups_only_week_varies / num_groups
    pct_week_and_others = 100 * groups_week_and_others_vary / num_groups
    pct_week_constant = 100 * groups_week_constant / num_groups
    
    print(f"Results:")
    print(f"  Groups where ONLY REPORT_YEAR_WEEK varies: {groups_only_week_varies:,} ({pct_only_week:.2f}%)")
    print(f"  Groups where REPORT_YEAR_WEEK + other columns vary: {groups_week_and_others_vary:,} ({pct_week_and_others:.2f}%)")
    print(f"  Groups where REPORT_YEAR_WEEK is constant: {groups_week_constant:,} ({pct_week_constant:.2f}%)")
    
    print("\n" + "=" * 80)
    print("INTERPRETATION:")
    print("=" * 80)
    print(f"✓ {pct_only_week:.1f}% of duplicate groups differ ONLY in REPORT_YEAR_WEEK")
    print(f"  → These are the same record appearing in multiple weekly reports")
    print()
    print(f"✓ {pct_week_and_others:.1f}% differ in REPORT_YEAR_WEEK AND other columns")
    print(f"  → These records changed over time (price, location, etc.)")
    print()
    print(f"✓ {pct_week_constant:.1f}% have the SAME REPORT_YEAR_WEEK")
    print(f"  → These are true duplicates within the same week")
    print("=" * 80)
    
    return {
        'summary': {
            'total_groups': num_groups,
            'only_week_varies': groups_only_week_varies,
            'week_and_others_vary': groups_week_and_others_vary,
            'week_constant': groups_week_constant,
            'pct_only_week': pct_only_week,
            'pct_week_and_others': pct_week_and_others,
            'pct_week_constant': pct_week_constant
        },
        'details': week_variation_details
    }

# Run the analysis
week_analysis = analyze_report_week_as_only_difference(full_df_live, duplicate_check_cols)

# %%
# Show some examples of groups where ONLY the week varies
print("\n" + "=" * 80)
print("SAMPLE GROUPS WHERE ONLY REPORT_YEAR_WEEK VARIES")
print("=" * 80)

only_week_examples = [d for d in week_analysis['details'] if d['category'] == 'ONLY_WEEK_VARIES']

if only_week_examples:
    # Sort by group size and show top 5
    only_week_examples_sorted = sorted(only_week_examples, key=lambda x: x['group_size'], reverse=True)
    
    print(f"\nShowing top 5 largest groups (out of {len(only_week_examples):,} total):\n")
    
    for i, example in enumerate(only_week_examples_sorted[:5], 1):
        print(f"{i}. Group with {example['group_size']} rows across {example['num_weeks']} weeks")
        print(f"   Weeks: {example['weeks']}")
        print()
    
    # Show distribution of how many weeks duplicates span
    week_counts = [d['num_weeks'] for d in only_week_examples]
    week_count_dist = pd.Series(week_counts).value_counts().sort_index()
    
    print("\nDistribution of weeks spanned by 'only week varies' groups:")
    print(f"{'Num Weeks':<12} {'Count':<12} {'Percentage'}")
    print("-" * 40)
    for num_weeks, count in week_count_dist.items():
        pct = 100 * count / len(only_week_examples)
        print(f"{num_weeks:<12} {count:<12,} {pct:>6.2f}%")
else:
    print("\nNo groups found where only REPORT_YEAR_WEEK varies.")

# %% [markdown]
# ## Find Duplicate Groups Where INV_LST_PRCE_AMT Varies
#
# Looking for duplicate groups where the list price (INV_LST_PRCE_AMT) has different values.

# %%
# Find duplicate groups where INV_LST_PRCE_AMT varies
# Filter for groups where INV_LST_PRCE_AMT_unique_count > 1 AND group size between 6 and 10
price_varying_groups = results[
    (results['INV_LST_PRCE_AMT_unique_count'] > 1) &
    (results['duplicate_group_size'] >= 6) &
    (results['duplicate_group_size'] <= 10)
].copy()

print(f"Found {len(price_varying_groups):,} duplicate groups where:")
print(f"  - INV_LST_PRCE_AMT varies")
print(f"  - Group size is between 6 and 10 rows")
print(f"That's {100*len(price_varying_groups)/len(results):.2f}% of all duplicate groups")
print("\n" + "="*80)
print("Groups with price variations (group size 6-10, sorted by group size):")
print("="*80)

# Show top 20 by group size
for i, (idx, row) in enumerate(price_varying_groups.head(20).iterrows(), 1):
    print(f"\n{'='*80}")
    print(f"GROUP {i} - Size: {row['duplicate_group_size']:,} rows")
    print(f"{'='*80}")
    
    # Show ALL duplicate check columns (these define the group)
    print("\nDuplicate Check Columns (what makes this a group):")
    for col in duplicate_check_cols:
        print(f"  {col}: {row[col]}")
    
    # Show variation info
    print(f"\nPrice Variations:")
    print(f"  INV_LST_PRCE_AMT: {row['INV_LST_PRCE_AMT_unique_count']} unique values - {row['INV_LST_PRCE_AMT_values']}")
    
    # Show other variation columns summary
    print(f"\nOther Variations:")
    for col in variation_cols:
        if col != 'INV_LST_PRCE_AMT':
            unique_count = row[f'{col}_unique_count']
            if unique_count > 1:
                values = row[f'{col}_values']
                print(f"  {col}: {unique_count} unique values - {values}")
# Out:
# Found 1,352,764 duplicate groups where:
#   - INV_LST_PRCE_AMT varies
#   - Group size is between 6 and 10 rows
# That's 25.43% of all duplicate groups
#
# ================================================================================
# Groups with price variations (group size 6-10, sorted by group size):
# ================================================================================
#
# ================================================================================
# GROUP 1 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 2025-09-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-06-25 00:00:00
#   TRIM_DESCRIPTION: SEL SPORT
#   INV_CENSUS_TRACT: 37155009613
#   INV_CONTROL_NBR: 0545961
#   INV_DEALER_NAME: ALM HYUNDAI LUMBERTON
#   INV_TOWN_NAME: LUMBERTON
#   INV_STATE_ABBRV: NC
#   MAKE_DESC: HYUNDAI
#   MODEL_DESC: ELANTRA
#   SERIES_TEXT: SLS
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: *COMPACT CAR
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 148799
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 4 unique values - 23772.0, 25165.0, 25105.0, 23717.0
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 25165.0, 25105.0
#
# ================================================================================
# GROUP 2 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 2025-09-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-06-25 00:00:00
#   TRIM_DESCRIPTION: SEL SPORT
#   INV_CENSUS_TRACT: 13059001305
#   INV_CONTROL_NBR: 0385620
#   INV_DEALER_NAME: ALM HYUNDAI ATHENS
#   INV_TOWN_NAME: ATHENS
#   INV_STATE_ABBRV: GA
#   MAKE_DESC: HYUNDAI
#   MODEL_DESC: ELANTRA
#   SERIES_TEXT: SLS
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: *COMPACT CAR
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 148799
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 5 unique values - 25165.0, 25105.0, 23717.0, 23772.0, 24467.0
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 25165.0, 25105.0
#
# ================================================================================
# GROUP 3 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 2025-09-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-06-25 00:00:00
#   TRIM_DESCRIPTION: S
#   INV_CENSUS_TRACT: 06059000525
#   INV_CONTROL_NBR: 0007030
#   INV_DEALER_NAME: NISSAN OF TUSTIN
#   INV_TOWN_NAME: TUSTIN
#   INV_STATE_ABBRV: CA
#   MAKE_DESC: NISSAN
#   MODEL_DESC: VERSA
#   SERIES_TEXT: S
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: SUB COMPACT CAR
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 149882
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 2 unique values - 20445.0, 21388.0
#
# Other Variations:
#   VEH_AT_PHYS_LOC: 2 unique values - Y, N
#   INV_MSRP_AMT: 2 unique values - 20695.0, 21945.0
#   NVI_CONTROL_NBR: 2 unique values - 0265797, 0266346
#
# ================================================================================
# GROUP 4 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2023-03-24 00:00:00
#   TRIM_DESCRIPTION: BASE
#   INV_CENSUS_TRACT: 45053009502
#   INV_CONTROL_NBR: 0221796
#   INV_DEALER_NAME: O C WELCH FORD
#   INV_TOWN_NAME: HARDEEVILLE
#   INV_STATE_ABBRV: SC
#   MAKE_DESC: FORD
#   MODEL_DESC: ECONOLINE
#   SERIES_TEXT: 450
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: LARGE MPV
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 126765
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 4 unique values - 64793.0, 56799.0, 55698.0, 57698.0
#
# Other Variations:
#
# ================================================================================
# GROUP 5 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-05-22 00:00:00
#   TRIM_DESCRIPTION: BASE
#   INV_CENSUS_TRACT: 06059001106
#   INV_CONTROL_NBR: 0004129
#   INV_DEALER_NAME: BMW OF BUENA PARK
#   INV_TOWN_NAME: BUENA PARK
#   INV_STATE_ABBRV: CA
#   MAKE_DESC: BMW
#   MODEL_DESC: 430
#   SERIES_TEXT: I
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY CAR
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 151439
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 2 unique values - 59220.0, 58520.0
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 59220.0, 58520.0
#
# ================================================================================
# GROUP 6 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-03-21 00:00:00
#   TRIM_DESCRIPTION: EDRIVE 40
#   INV_CENSUS_TRACT: 04013001076
#   INV_CONTROL_NBR: 0344783
#   INV_DEALER_NAME: CHAPMAN BMW ON CAMELBACK
#   INV_TOWN_NAME: PHOENIX
#   INV_STATE_ABBRV: AZ
#   MAKE_DESC: BMW
#   MODEL_DESC: I5
#   SERIES_TEXT: E40
#   FUEL_DESC: ELECTRIC
#   SEGMENT_DESC: MID-LUXURY EV CAR
#   ADVNC_VEH_TYPE_DESC: Electric Vehicle
#   MODEL_KEY_SHORT: 152937
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 2 unique values - 77040.0, 72940.0
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 77040.0, 72940.0
#
# ================================================================================
# GROUP 7 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-05-22 00:00:00
#   TRIM_DESCRIPTION: 300 4MATIC
#   INV_CENSUS_TRACT: 34035000510
#   INV_CONTROL_NBR: 0023612
#   INV_DEALER_NAME: OPEN ROAD OF BRIDGEWATER
#   INV_TOWN_NAME: BRIDGEWATER
#   INV_STATE_ABBRV: NJ
#   MAKE_DESC: MERCEDES-BENZ
#   MODEL_DESC: GLC
#   SERIES_TEXT: 300
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: NEAR LUXURY SUV
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 149629
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 5 unique values - 57259.0, 55030.0, 60614.0, 56260.0, 56029.0
#
# Other Variations:
#   INV_MSRP_AMT: 5 unique values - 57259.0, 55030.0, 60614.0, 56260.0, 56029.0
#
# ================================================================================
# GROUP 8 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-31 00:00:00
#   TRIM_DESCRIPTION: SEL
#   INV_CENSUS_TRACT: 36103001468
#   INV_CONTROL_NBR:
#   INV_DEALER_NAME:
#   INV_TOWN_NAME:
#   INV_STATE_ABBRV:
#   MAKE_DESC: HYUNDAI
#   MODEL_DESC: SANTA FE
#   SERIES_TEXT: SEL
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: *COMPACT SUV
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 151987
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 3 unique values - 42300.0, 41755.0, 41730.0
#
# Other Variations:
#   INV_MSRP_AMT: 3 unique values - 42300.0, 41755.0, 41730.0
#
# ================================================================================
# GROUP 9 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-09-18 00:00:00
#   TRIM_DESCRIPTION: 1500 HIGH COUNTRY
#   INV_CENSUS_TRACT: 36063000226
#   INV_CONTROL_NBR: 0012059
#   INV_DEALER_NAME: DAVID CHEVROLET INC
#   INV_TOWN_NAME: NIAGARA FALLS
#   INV_STATE_ABBRV: NY
#   MAKE_DESC: CHEVROLET
#   MODEL_DESC: TAHOE
#   SERIES_TEXT: 150
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: LARGE SUV
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 154478
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 4 unique values - 95705.0, 85380.0, 92705.0, 88380.0
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 95705.0, 88380.0
#
# ================================================================================
# GROUP 10 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-09-18 00:00:00
#   TRIM_DESCRIPTION: 1500 ELEVATION-L
#   INV_CENSUS_TRACT: 27145000004
#   INV_CONTROL_NBR: 0126537
#   INV_DEALER_NAME: MILLER BUICK GMC
#   INV_TOWN_NAME: SAINT CLOUD
#   INV_STATE_ABBRV: MN
#   MAKE_DESC: GMC
#   MODEL_DESC: SIERRA
#   SERIES_TEXT: 15P
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: LARGE PICKUP
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 153186
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 4 unique values - 57990.0, 52990.0, 57495.0, 52495.0
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 57990.0, 57495.0
#
# ================================================================================
# GROUP 11 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-09-18 00:00:00
#   TRIM_DESCRIPTION: 1500 ELEVATION
#   INV_CENSUS_TRACT: 53067000105
#   INV_CONTROL_NBR: 0015801
#   INV_DEALER_NAME: TITUS WILL CHEVROLET GMC
#   INV_TOWN_NAME: OLYMPIA
#   INV_STATE_ABBRV: WA
#   MAKE_DESC: GMC
#   MODEL_DESC: SIERRA
#   SERIES_TEXT: 15P
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: LARGE PICKUP
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 153186
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 4 unique values - 64675.0, 65175.0, 65170.0, 65670.0
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 67925.0, 68420.0
#
# ================================================================================
# GROUP 12 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-09-18 00:00:00
#   TRIM_DESCRIPTION: 1500 ELEVATION
#   INV_CENSUS_TRACT: 55025000014
#   INV_CONTROL_NBR: 0003958
#   INV_DEALER_NAME: ZIMBRICK INFINITI MADISON
#   INV_TOWN_NAME: FITCHBURG
#   INV_STATE_ABBRV: WI
#   MAKE_DESC: GMC
#   MODEL_DESC: SIERRA
#   SERIES_TEXT: 15P
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: LARGE PICKUP
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 153186
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 5 unique values - 67017.0, 65635.0, 66635.0, 67130.0, 67502.0
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 68385.0, 68880.0
#
# ================================================================================
# GROUP 13 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-09-18 00:00:00
#   TRIM_DESCRIPTION: 1500 HIGH COUNTRY
#   INV_CENSUS_TRACT: 45051000509
#   INV_CONTROL_NBR: 0019528
#   INV_DEALER_NAME: MYRTLE BEACH CHEVROLET CADILLAC
#   INV_TOWN_NAME: MYRTLE BEACH
#   INV_STATE_ABBRV: SC
#   MAKE_DESC: CHEVROLET
#   MODEL_DESC: TAHOE
#   SERIES_TEXT: 150
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: LARGE SUV
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 154478
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 4 unique values - 91579.0, 94504.0, 92004.0, 94079.0
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 94079.0, 94504.0
#
# ================================================================================
# GROUP 14 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-05-02 00:00:00
#   TRIM_DESCRIPTION: BASE
#   INV_CENSUS_TRACT: 06037004617
#   INV_CONTROL_NBR: 0022042
#   INV_DEALER_NAME: RUSNAK PASADENA
#   INV_TOWN_NAME: PASADENA
#   INV_STATE_ABBRV: CA
#   MAKE_DESC: PORSCHE
#   MODEL_DESC: PANAMERA
#   SERIES_TEXT: MTL
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: PREMIUM LUXURY CAR
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 149466
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 2 unique values - 118475.0, 130445.0
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 118475.0, 130445.0
#
# ================================================================================
# GROUP 15 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-18 00:00:00
#   TRIM_DESCRIPTION: XLE PREMIUM
#   INV_CENSUS_TRACT: 17081000505
#   INV_CONTROL_NBR: 0037136
#   INV_DEALER_NAME: MONKEN TOYOTA OF MT VERNON
#   INV_TOWN_NAME: MOUNT VERNON
#   INV_STATE_ABBRV: IL
#   MAKE_DESC: TOYOTA
#   MODEL_DESC: RAV4
#   SERIES_TEXT: 4
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: *SUBCOMPACT SUV
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 150230
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 4 unique values - 40577.0, 42876.0, 42786.0, 40667.0
#
# Other Variations:
#   INV_MSRP_AMT: 4 unique values - 40577.0, 42876.0, 42786.0, 40667.0
#
# ================================================================================
# GROUP 16 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-19 00:00:00
#   TRIM_DESCRIPTION:
#   INV_CENSUS_TRACT: 48201003341
#   INV_CONTROL_NBR: 0164231
#   INV_DEALER_NAME: AUTONATION CHRYSLER DODGE JEEP RAM HOUST
#   INV_TOWN_NAME: HOUSTON
#   INV_STATE_ABBRV: TX
#   MAKE_DESC: RAM
#   MODEL_DESC: RAM
#   SERIES_TEXT: 150
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: LARGE PICKUP
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 153215
#   INV_COUNT: 4.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 4 unique values - 58165.0, 58340.0, 57715.0, 61840.0
#
# Other Variations:
#   INV_MSRP_AMT: 3 unique values - 61665.0, 61840.0, 61215.0
#
# ================================================================================
# GROUP 17 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 1899-12-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-08-19 00:00:00
#   TRIM_DESCRIPTION:
#   INV_CENSUS_TRACT: 48201004546
#   INV_CONTROL_NBR: 0154222
#   INV_DEALER_NAME: AUTONATION CHRYSLER DODGE JEEP RAM KATY
#   INV_TOWN_NAME: KATY
#   INV_STATE_ABBRV: TX
#   MAKE_DESC: RAM
#   MODEL_DESC: RAM
#   SERIES_TEXT: 150
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: LARGE PICKUP
#   ADVNC_VEH_TYPE_DESC: Mild Hybrid Electric Vehicle Gasoline
#   MODEL_KEY_SHORT: 153215
#   INV_COUNT: 4.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 4 unique values - 58340.0, 58165.0, 57715.0, 61215.0
#
# Other Variations:
#   INV_MSRP_AMT: 3 unique values - 61840.0, 61665.0, 61215.0
#
# ================================================================================
# GROUP 18 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 2025-09-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-06-25 00:00:00
#   TRIM_DESCRIPTION: SEL SPORT
#   INV_CENSUS_TRACT: 45041000002
#   INV_CONTROL_NBR: 0178928
#   INV_DEALER_NAME: ALM HYUNDAI FLORENCE
#   INV_TOWN_NAME: FLORENCE
#   INV_STATE_ABBRV: SC
#   MAKE_DESC: HYUNDAI
#   MODEL_DESC: ELANTRA
#   SERIES_TEXT: SLS
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: *COMPACT CAR
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 148799
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 4 unique values - 25165.0, 23772.0, 23717.0, 25105.0
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 25165.0, 25105.0
#
# ================================================================================
# GROUP 19 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 2025-09-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-06-25 00:00:00
#   TRIM_DESCRIPTION: SV
#   INV_CENSUS_TRACT: 06059000525
#   INV_CONTROL_NBR: 0007030
#   INV_DEALER_NAME: NISSAN OF TUSTIN
#   INV_TOWN_NAME: TUSTIN
#   INV_STATE_ABBRV: CA
#   MAKE_DESC: NISSAN
#   MODEL_DESC: SENTRA
#   SERIES_TEXT: SV
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: *COMPACT CAR
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 149247
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 6 unique values - 23470.0, 23970.0, 22635.0, 23635.0, 23135.0 ... (6 total)
#
# Other Variations:
#   INV_MSRP_AMT: 2 unique values - 25300.0, 24915.0
#
# ================================================================================
# GROUP 20 - Size: 10 rows
# ================================================================================
#
# Duplicate Check Columns (what makes this a group):
#   INV_MIN_VIN_SOLD_DT: 2025-09-30 00:00:00
#   SRC_VEH_FIRST_SCRAPED_DT: 2025-06-25 00:00:00
#   TRIM_DESCRIPTION: PLATINUM
#   INV_CENSUS_TRACT: 40109001073
#   INV_CONTROL_NBR:
#   INV_DEALER_NAME:
#   INV_TOWN_NAME:
#   INV_STATE_ABBRV:
#   MAKE_DESC: NISSAN
#   MODEL_DESC: MURANO
#   SERIES_TEXT: PLT
#   FUEL_DESC: GASOLINE
#   SEGMENT_DESC: *COMPACT SUV
#   ADVNC_VEH_TYPE_DESC: Gasoline
#   MODEL_KEY_SHORT: 150221
#   INV_COUNT: 1.0
#
# Price Variations:
#   INV_LST_PRCE_AMT: 3 unique values - 40331.0, 50565.0, 49631.0
#
# Other Variations:
#   VIN_SOLD: 2 unique values - 2.0, 1.0
#   INV_MSRP_AMT: 2 unique values - 51845.0, 50765.0
#   NVI_CONTROL_NBR: 2 unique values - 0266144, 0007243

# %%
# Get the actual rows from the first duplicate group with price variations
# This will show you all the rows that belong to that group

if len(price_varying_groups) > 0:
    # Get the first group's identifying values
    first_group = price_varying_groups.iloc[0]
    
    print(f"Fetching all rows for the largest duplicate group with price variations...")
    print(f"Group size: {first_group['duplicate_group_size']:,} rows")
    print("="*80)
    
    # Build a filter to get all rows from this duplicate group
    filter_mask = pd.Series(True, index=full_df_live.index)
    for col in duplicate_check_cols:
        filter_mask &= (full_df_live[col] == first_group[col])
    
    # Get the actual rows
    example_group = full_df_live[filter_mask].copy()
    
    # Display key columns including the varying price
    display_cols = ['REPORT_YEAR_WEEK', 'VEH_AT_PHYS_LOC', 'INV_LST_PRCE_AMT', 'INV_MSRP_AMT', 
                    'VIN_SOLD', 'DAYS_LSTD_BFR_SLD', 'INV_DEALER_NAME', 'MAKE_DESC', 'MODEL_DESC']
    
    print(f"\nShowing key columns for this duplicate group:")
    print(example_group[display_cols].to_string())
    
    print(f"\n\nINV_LST_PRCE_AMT value counts in this group:")
    print(example_group['INV_LST_PRCE_AMT'].value_counts())
else:
    print("No duplicate groups with price variations found!")
# Out:
# Fetching all rows for the largest duplicate group with price variations...
# Group size: 424 rows
# ================================================================================
#
# Showing key columns for this duplicate group:
#          REPORT_YEAR_WEEK VEH_AT_PHYS_LOC  INV_LST_PRCE_AMT  INV_MSRP_AMT  VIN_SOLD  DAYS_LSTD_BFR_SLD      INV_DEALER_NAME   MAKE_DESC   MODEL_DESC
# 9754              2025-42               N          159095.0      159095.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 115133            2025-40               N          130900.0      130900.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 156267            2025-40               N          159950.0      159950.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 166297            2025-41               N          151325.0      151325.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 275320            2025-41               N          150330.0      150330.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 509258            2025-42               N          145050.0      145050.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 556243            2025-41               N          160215.0      160215.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 680817            2025-42               N          153625.0      153625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 731490            2025-40               N          134890.0      134890.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 737531            2025-41               N          128995.0      128995.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 810274            2025-42               N          149820.0      149820.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 819838            2025-41               N          160310.0      160310.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 925474            2025-42               N          126915.0      126915.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1025235           2025-42               N          131090.0      131090.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1176778           2025-41               N          162905.0      162905.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1229905           2025-42               N          156640.0      156640.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1408053           2025-40               N          148910.0      148910.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1483233           2025-41               N          154410.0      154410.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1490398           2025-42               N          151330.0      151330.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1643668           2025-41               N          148910.0      148910.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1680470           2025-40               N          148130.0      148130.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1725869           2025-41               N          120750.0      120750.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1741516           2025-40               N          130625.0      130625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1854549           2025-41               N          130625.0      130625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 1882266           2025-40               N          149960.0      149960.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2205913           2025-40               N          158950.0      158950.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2263637           2025-41               N          131975.0      131975.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2263865           2025-40               N          151330.0      151330.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2283079           2025-40               N          125150.0      125150.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2369887           2025-40               N          160215.0      160215.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2390630           2025-40               N          124565.0      124565.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2547082           2025-40               N          144630.0      144630.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2652041           2025-41               N          150105.0      150105.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2677549           2025-40               N          151325.0      151325.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2722620           2025-42               N          154495.0      154495.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2805335           2025-40               N          142120.0      142120.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2866366           2025-41               N          158870.0      158870.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2907656           2025-40               N          140615.0      140615.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 2945428           2025-42               N          139745.0      139745.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3169108           2025-40               N          156415.0      156415.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3228822           2025-40               N          126915.0      126915.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3250314           2025-40               N          120975.0      120975.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3292612           2025-40               N          123275.0      123275.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3307572           2025-42               N          143205.0      143205.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3383441           2025-42               N          134890.0      134890.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3519710           2025-41               N          153455.0      153455.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3576303           2025-41               N          149510.0      149510.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3660703           2025-42               N          120750.0      120750.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3757426           2025-42               N          148130.0      148130.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3759240           2025-41               N          152065.0      152065.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3776629           2025-42               N          143800.0      143800.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 3888855           2025-41               N          152710.0      152710.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 4156895           2025-42               N          125175.0      125175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 4189247           2025-40               N          156640.0      156640.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 4310501           2025-40               N          152010.0      152010.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 4374020           2025-42               N          151650.0      151650.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 4413532           2025-41               N          139745.0      139745.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 4473689           2025-41               N          154495.0      154495.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 4532450           2025-41               N          121325.0      121325.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 4556350           2025-40               N          132425.0      132425.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 4569050           2025-41               N          128785.0      128785.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 4617749           2025-42               N          148810.0      148810.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 4805378           2025-40               N          126515.0      126515.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5022289           2025-42               N          144175.0      144175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5078341           2025-41               N          141060.0      141060.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5169977           2025-40               N          157035.0      157035.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5204629           2025-40               N          141060.0      141060.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5275774           2025-40               N          139745.0      139745.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5309872           2025-41               N          151360.0      151360.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5315283           2025-40               N          129760.0      129760.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5345115           2025-42               N          131340.0      131340.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5351853           2025-40               N          123025.0      123025.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5463642           2025-41               N          125175.0      125175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5515619           2025-41               N          143800.0      143800.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5674856           2025-40               N          125175.0      125175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5712671           2025-40               N          123225.0      123225.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5873844           2025-42               N          153790.0      153790.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 5962282           2025-41               N          149805.0      149805.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6005257           2025-42               N          132150.0      132150.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6034511           2025-42               N          144910.0      144910.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6201600           2025-40               N          167620.0      167620.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6367359           2025-40               N          154790.0      154790.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6372006           2025-41               N          158950.0      158950.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6423833           2025-42               N          161100.0      161100.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6434319           2025-42               N          162985.0      162985.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6621111           2025-42               N          152035.0      152035.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6710616           2025-41               N          144725.0      144725.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6741424           2025-41               N          123225.0      123225.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6751632           2025-42               N          125695.0      125695.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6834021           2025-40               N          142825.0      142825.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 6993187           2025-41               N          124565.0      124565.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7097837           2025-40               N          131340.0      131340.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7239980           2025-42               N          166075.0      166075.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7264818           2025-42               N          151325.0      151325.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7319763           2025-41               N          130900.0      130900.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7346104           2025-41               N          156640.0      156640.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7373886           2025-42               N          128925.0      128925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7457067           2025-40               N          164685.0      164685.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7546185           2025-41               N          160705.0      160705.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7558213           2025-42               N          125150.0      125150.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7681499           2025-40               N          149305.0      149305.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7748377           2025-41               N          120755.0      120755.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7765614           2025-41               N          132175.0      132175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 7773920           2025-42               N          140815.0      140815.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 8169606           2025-40               N          132175.0      132175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 8243061           2025-40               N          147675.0      147675.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 8250035           2025-42               N          149535.0      149535.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 8335435           2025-42               N          157985.0      157985.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 8394169           2025-41               N          141175.0      141175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 8399906           2025-42               N          120480.0      120480.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 8445137           2025-40               N          168930.0      168930.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 8494254           2025-40               N          149510.0      149510.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 8547812           2025-41               N          152860.0      152860.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 8623990           2025-41               N          125150.0      125150.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9006163           2025-42               N          144725.0      144725.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9015135           2025-41               N          120955.0      120955.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9109460           2025-41               N          148810.0      148810.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9191455           2025-41               N          132425.0      132425.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9198310           2025-41               N          150110.0      150110.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9339212           2025-40               N          151310.0      151310.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9423961           2025-40               N          118215.0      118215.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9579350           2025-41               N          148805.0      148805.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9698499           2025-41               N          131925.0      131925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9778949           2025-41               N          145940.0      145940.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9794475           2025-42               N          154415.0      154415.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9801001           2025-41               N          151310.0      151310.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 9909353           2025-40               N          145050.0      145050.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10003384          2025-42               N          132175.0      132175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10046665          2025-42               N          164685.0      164685.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10100898          2025-41               N          123000.0      123000.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10104210          2025-41               N          153935.0      153935.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10156015          2025-40               N          122475.0      122475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10163169          2025-40               N          152860.0      152860.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10271809          2025-42               N          168930.0      168930.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10432920          2025-42               N          150330.0      150330.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10457527          2025-40               N          152930.0      152930.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10643583          2025-40               N          128785.0      128785.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10678947          2025-41               N          148130.0      148130.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10685620          2025-40               N          143800.0      143800.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10801976          2025-40               N          141650.0      141650.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10810634          2025-42               N          150105.0      150105.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 10922598          2025-40               N          157985.0      157985.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11077726          2025-40               N          160705.0      160705.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11131844          2025-42               N          150360.0      150360.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11137540          2025-41               N          143190.0      143190.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11138408          2025-42               N          128995.0      128995.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11190025          2025-41               N          131430.0      131430.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11223177          2025-42               N          148300.0      148300.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11227742          2025-42               N          166050.0      166050.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11246377          2025-40               N          152925.0      152925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11247137          2025-40               N          161590.0      161590.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11248064          2025-40               N          159095.0      159095.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11253907          2025-40               N          144910.0      144910.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11260068          2025-42               N          158870.0      158870.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11314734          2025-42               N          123025.0      123025.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11402756          2025-40               N          152035.0      152035.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11482985          2025-40               N          160905.0      160905.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11522450          2025-42               N          143190.0      143190.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11547640          2025-41               N          120480.0      120480.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11642664          2025-42               N          131430.0      131430.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11664197          2025-41               N          152930.0      152930.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11752576          2025-40               N          149535.0      149535.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11786214          2025-42               N          141060.0      141060.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11838332          2025-42               N          156355.0      156355.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11911735          2025-41               N          159000.0      159000.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11928668          2025-40               N          152065.0      152065.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11934748          2025-40               N          147005.0      147005.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 11985945          2025-40               N          134265.0      134265.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12060734          2025-41               N          167625.0      167625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12130526          2025-40               N          118305.0      118305.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12155576          2025-42               N          152555.0      152555.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12218749          2025-42               N          149510.0      149510.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12224552          2025-40               N          162905.0      162905.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12258313          2025-42               N          153455.0      153455.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12316260          2025-41               N          132150.0      132150.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12325635          2025-41               N          142120.0      142120.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12642846          2025-41               N          155955.0      155955.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12653004          2025-42               N          159475.0      159475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12670771          2025-42               N          131975.0      131975.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12713316          2025-40               N          159475.0      159475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12784978          2025-41               N          152925.0      152925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12867324          2025-41               N          130900.0      130900.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12879979          2025-40               N          128785.0      128785.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 12974400          2025-40               N          143925.0      143925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13009645          2025-40               N          151360.0      151360.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13020594          2025-40               N          140815.0      140815.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13071733          2025-40               N          166075.0      166075.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13193041          2025-40               N          149820.0      149820.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13208179          2025-42               N          152930.0      152930.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13339980          2025-42               N          142825.0      142825.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13420420          2025-41               N          144175.0      144175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13470445          2025-41               N          149535.0      149535.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13620995          2025-40               N          150110.0      150110.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13752585          2025-41               N          133885.0      133885.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13805095          2025-42               N          148910.0      148910.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13817618          2025-42               N          162905.0      162905.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13834153          2025-42               N          165925.0      165925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13879230          2025-40               N          154410.0      154410.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13923073          2025-42               N          130475.0      130475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13947032          2025-41               N          122475.0      122475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13956394          2025-42               N          160905.0      160905.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 13979297          2025-40               N          162985.0      162985.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 14158910          2025-40               N          167625.0      167625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 14163262          2025-42               N          130900.0      130900.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 14168102          2025-40               N          159000.0      159000.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 14194548          2025-41               N          164685.0      164685.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 14400422          2025-40               N          150360.0      150360.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 14431890          2025-42               N          142825.0      142825.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 14451012          2025-41               N          151330.0      151330.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 14478108          2025-41               N          160905.0      160905.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 14512001          2025-41               N          159950.0      159950.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 14948748          2025-42               N          160705.0      160705.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 15143449          2025-41               N          166050.0      166050.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 15378827          2025-41               N          150360.0      150360.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 15455592          2025-42               N          145940.0      145940.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 15457822          2025-40               N          156355.0      156355.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 15474352          2025-40               N          142825.0      142825.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 15698949          2025-40               N          144860.0      144860.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 15721120          2025-42               N          150110.0      150110.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 15727993          2025-40               N          137965.0      137965.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 15813480          2025-40               N          120480.0      120480.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 15843177          2025-40               N          148805.0      148805.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 15855675          2025-42               N          159000.0      159000.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16001450          2025-40               N          144175.0      144175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16032999          2025-40               N          154415.0      154415.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16063404          2025-40               N          150105.0      150105.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16089766          2025-41               N          131615.0      131615.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16126729          2025-40               N          155955.0      155955.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16163345          2025-42               N          153935.0      153935.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16257844          2025-40               N          154010.0      154010.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16290497          2025-40               N          131615.0      131615.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16332844          2025-42               N          151310.0      151310.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16387494          2025-41               N          148475.0      148475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16527942          2025-40               N          132285.0      132285.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16533786          2025-41               N          153810.0      153810.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16559102          2025-42               N          141560.0      141560.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16573078          2025-42               N          152925.0      152925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16650643          2025-41               N          165925.0      165925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16723533          2025-41               N          161100.0      161100.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16757426          2025-41               N          162985.0      162985.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16791344          2025-40               N          128925.0      128925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16818358          2025-42               N          130585.0      130585.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16866827          2025-41               N          131090.0      131090.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16874809          2025-40               N          154495.0      154495.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 16906620          2025-40               N          143190.0      143190.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17018828          2025-42               N          122475.0      122475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17027854          2025-40               N          128995.0      128995.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17079663          2025-40               N          152555.0      152555.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17098789          2025-40               N          125695.0      125695.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17151321          2025-41               N          151650.0      151650.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17236137          2025-40               N          148810.0      148810.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17411671          2025-40               N          131090.0      131090.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17416403          2025-42               N          137965.0      137965.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17425251          2025-41               N          151625.0      151625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17428645          2025-41               N          148960.0      148960.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17538757          2025-42               N          132285.0      132285.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17650154          2025-40               N          152015.0      152015.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17806818          2025-42               N          154790.0      154790.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17881189          2025-40               N          153810.0      153810.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17938400          2025-40               N          136020.0      136020.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17955451          2025-41               N          159095.0      159095.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 17998670          2025-40               N          130835.0      130835.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 18128298          2025-40               N          148475.0      148475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 18481673          2025-42               N          149305.0      149305.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 18551709          2025-41               N          131340.0      131340.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 18657389          2025-42               N          160215.0      160215.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 18808352          2025-42               N          149805.0      149805.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 18858265          2025-40               N          130475.0      130475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 18907192          2025-42               N          153810.0      153810.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 18915153          2025-41               N          123025.0      123025.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 18920122          2025-40               N          131925.0      131925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19017973          2025-41               N          149305.0      149305.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19066214          2025-42               N          118215.0      118215.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19147516          2025-41               N          154010.0      154010.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19207865          2025-40               N          158385.0      158385.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19225592          2025-40               N          121325.0      121325.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19266835          2025-42               N          152015.0      152015.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19343059          2025-40               N          136925.0      136925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19360179          2025-40               N          148960.0      148960.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19521072          2025-40               N          161100.0      161100.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19555383          2025-42               N          148805.0      148805.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19625548          2025-42               N          142120.0      142120.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19719485          2025-42               N          140615.0      140615.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19895820          2025-41               N          125695.0      125695.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 19948317          2025-41               N          152010.0      152010.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20070377          2025-40               N          144950.0      144950.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20074455          2025-42               N          148475.0      148475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20176182          2025-40               N          153790.0      153790.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20221247          2025-40               N          150330.0      150330.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20556739          2025-40               N          123000.0      123000.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20558316          2025-40               N          141175.0      141175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20657054          2025-40               N          143205.0      143205.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20662024          2025-41               N          154790.0      154790.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20737312          2025-41               N          168930.0      168930.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20814768          2025-40               N          148300.0      148300.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20973445          2025-42               N          144860.0      144860.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 20992276          2025-40               N          120955.0      120955.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 21048965          2025-41               N          130585.0      130585.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 21122923          2025-41               N          134890.0      134890.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 21261415          2025-41               N          141560.0      141560.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 21337139          2025-41               N          153625.0      153625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 21419105          2025-42               N          136020.0      136020.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 21589748          2025-41               N          151805.0      151805.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 21597439          2025-41               N          144950.0      144950.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 21788302          2025-41               N          148805.0      148805.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 21856558          2025-40               N          133885.0      133885.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 21878805          2025-41               N          156355.0      156355.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 21909404          2025-41               N          123275.0      123275.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 22139760          2025-40               N          153935.0      153935.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 22224835          2025-41               N          154145.0      154145.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 22343189          2025-41               N          143205.0      143205.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 22563586          2025-40               N          153625.0      153625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 22596825          2025-41               N          142825.0      142825.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 22599493          2025-41               N          154415.0      154415.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 22614031          2025-42               N          152710.0      152710.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 22889608          2025-42               N          154410.0      154410.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 22915437          2025-40               N          151805.0      151805.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 23018445          2025-40               N          152710.0      152710.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 23157986          2025-42               N          154010.0      154010.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# ...
# 24000515          2025-42               N          151625.0      151625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24174654          2025-41               N          142825.0      142825.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24244250          2025-41               N          147675.0      147675.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24292585          2025-41               N          118305.0      118305.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24414188          2025-41               N          140815.0      140815.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24464169          2025-40               N          131430.0      131430.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24591549          2025-41               N          148300.0      148300.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24598029          2025-42               N          149960.0      149960.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24618403          2025-41               N          144910.0      144910.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24619469          2025-42               N          152860.0      152860.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24627159          2025-40               N          144725.0      144725.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24720991          2025-40               N          160310.0      160310.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24751186          2025-42               N          167625.0      167625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24927441          2025-41               N          167620.0      167620.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 24937788          2025-42               N          148960.0      148960.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25029546          2025-40               N          131975.0      131975.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25049719          2025-42               N          154145.0      154145.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25182721          2025-41               N          130475.0      130475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25252986          2025-41               N          152015.0      152015.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25273177          2025-42               N          146460.0      146460.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25294647          2025-41               N          150330.0      150330.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25298381          2025-40               N          123810.0      123810.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25359347          2025-42               N          151360.0      151360.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25410937          2025-41               N          137965.0      137965.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25537342          2025-41               N          145050.0      145050.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25700460          2025-42               N          161690.0      161690.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25875354          2025-41               N          141650.0      141650.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 25886543          2025-41               N          161690.0      161690.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 26008525          2025-40               N          146460.0      146460.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 26151989          2025-42               N          118305.0      118305.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 26222205          2025-41               N          149820.0      149820.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 26283089          2025-41               N          143925.0      143925.0       3.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 26445884          2025-40               N          158870.0      158870.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 26469503          2025-42               N          130625.0      130625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 26499995          2025-41               N          166075.0      166075.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 26512958          2025-40               N          145940.0      145940.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 26655692          2025-42               N          152065.0      152065.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 26798561          2025-40               N          161690.0      161690.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 27061328          2025-42               N          143925.0      143925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 27079140          2025-42               N          179865.0      179865.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 27115636          2025-42               N          128785.0      128785.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 27117653          2025-42               N          147005.0      147005.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 27157970          2025-42               N          158385.0      158385.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 27572857          2025-42               N          161590.0      161590.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 27745506          2025-42               N          151805.0      151805.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 27763919          2025-41               N          134265.0      134265.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 27810187          2025-40               N          132150.0      132150.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 27956757          2025-40               N          120755.0      120755.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28011216          2025-40               N          120750.0      120750.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28040193          2025-42               N          133885.0      133885.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28041794          2025-41               N          149960.0      149960.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28046872          2025-40               N          141560.0      141560.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28084868          2025-41               N          140615.0      140615.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28186950          2025-41               N          159475.0      159475.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28237972          2025-40               N          125525.0      125525.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28242589          2025-42               N          126515.0      126515.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28285954          2025-41               N          153790.0      153790.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28340237          2025-41               N          144630.0      144630.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28402946          2025-42               N          144950.0      144950.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28460526          2025-40               N          151650.0      151650.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28497961          2025-41               N          136020.0      136020.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28618785          2025-41               N          147005.0      147005.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28668538          2025-41               N          139280.0      139280.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28688474          2025-40               N          166050.0      166050.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28867972          2025-41               N          152555.0      152555.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28917433          2025-40               N          150330.0      150330.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 28978189          2025-41               N          130835.0      130835.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29036315          2025-41               N          179865.0      179865.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29063960          2025-41               N          152035.0      152035.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29119452          2025-40               N          151625.0      151625.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29137679          2025-41               N          126915.0      126915.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29152307          2025-41               N          146460.0      146460.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29163728          2025-42               N          141650.0      141650.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29345984          2025-41               N          126515.0      126515.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29387303          2025-41               N          132285.0      132285.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29584960          2025-41               N          144860.0      144860.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29636036          2025-41               N          136925.0      136925.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29658901          2025-40               N          148805.0      148805.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 29938244          2025-40               N          149805.0      149805.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30046159          2025-42               N          120755.0      120755.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30060737          2025-42               N          131615.0      131615.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30093526          2025-42               N          124565.0      124565.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30094896          2025-40               N          130900.0      130900.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30165212          2025-42               N          155955.0      155955.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30185969          2025-42               N          123000.0      123000.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30310199          2025-41               N          161590.0      161590.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30331835          2025-42               N          141175.0      141175.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30345427          2025-40               N          153455.0      153455.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30490839          2025-41               N          158385.0      158385.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30492440          2025-42               N          139280.0      139280.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30498326          2025-42               N          144630.0      144630.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30546380          2025-42               N          132425.0      132425.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
# 30561033          2025-40               N          130585.0      130585.0       0.0             -999.0  JAGUAR SANTA MONICA  LAND ROVER  RANGE ROVER
#
#
# INV_LST_PRCE_AMT value counts in this group:
# INV_LST_PRCE_AMT
# 142825.0    6
# 150330.0    5
# 130900.0    5
# 148805.0    5
# 128785.0    4
# 145050.0    3
# 159095.0    3
# 159950.0    3
# 151325.0    3
# 128995.0    3
# 149820.0    3
# 126915.0    3
# 131090.0    3
# 156640.0    3
# 160215.0    3
# 153625.0    3
# 134890.0    3
# 151625.0    3
# 148910.0    3
# 162905.0    3
# 148130.0    3
# 130625.0    3
# 149960.0    3
# 131975.0    3
# 154410.0    3
# 154495.0    3
# 124565.0    3
# 144630.0    3
# 150105.0    3
# 158870.0    3
# 142120.0    3
# 140615.0    3
# 151330.0    3
# 152010.0    3
# 139745.0    3
# 153455.0    3
# 149510.0    3
# 152065.0    3
# 125175.0    3
# 143800.0    3
# 143205.0    3
# 132425.0    3
# 151650.0    3
# 152710.0    3
# 151360.0    3
# 126515.0    3
# 144175.0    3
# 148810.0    3
# 120750.0    3
# 164685.0    3
# 160705.0    3
# 149305.0    3
# 120755.0    3
# 144725.0    3
# 131340.0    3
# 153790.0    3
# 141060.0    3
# 154790.0    3
# 144910.0    3
# 149805.0    3
# 132150.0    3
# 162985.0    3
# 152035.0    3
# 161100.0    3
# 123025.0    3
# 132175.0    3
# 140815.0    3
# 149535.0    3
# 128925.0    3
# 166075.0    3
# 125695.0    3
# 118215.0    3
# 154415.0    3
# 168930.0    3
# 151310.0    3
# 150110.0    3
# 152860.0    3
# 141175.0    3
# 120480.0    3
# 157985.0    3
# 125150.0    3
# 146460.0    3
# 148960.0    3
# 159475.0    3
# 143925.0    3
# 133885.0    3
# 165925.0    3
# 130475.0    3
# 144860.0    3
# 137965.0    3
# 131615.0    3
# 131925.0    3
# 145940.0    3
# 153935.0    3
# 123000.0    3
# 122475.0    3
# 152930.0    3
# 161590.0    3
# 141650.0    3
# 150360.0    3
# 143190.0    3
# 131430.0    3
# 148300.0    3
# 166050.0    3
# 152925.0    3
# 147005.0    3
# 160905.0    3
# 156355.0    3
# 159000.0    3
# 118305.0    3
# 167625.0    3
# 155955.0    3
# 152555.0    3
# 179865.0    3
# 154145.0    3
# 152015.0    3
# 136020.0    3
# 158385.0    3
# 136925.0    3
# 144950.0    3
# 151805.0    3
# 161690.0    3
# 139280.0    3
# 154010.0    3
# 148475.0    3
# 132285.0    3
# 153810.0    3
# 141560.0    3
# 130585.0    3
# 160310.0    2
# 158950.0    2
# 156415.0    2
# 147675.0    2
# 123225.0    2
# 123275.0    2
# 121325.0    2
# 167620.0    2
# 134265.0    2
# 130835.0    2
# 120955.0    2
# 120975.0    1
# 129760.0    1
# 157035.0    1
# 123810.0    1
# 125525.0    1
# Name: count, dtype: int64
